# %% [markdown]
# # Actividad - Proyecto práctico
#
#
# > La actividad se desarrollará en grupos pre-definidos de 2-3 alumnos. Se debe indicar los nombres en orden alfabético (de apellidos). Recordad que esta actividad se corresponde con un 30% de la nota final de la asignatura. Se debe entregar entregar el trabajo en la presente notebook.
# *   Alumno 1: Granizo, Mateo
# *   Alumno 2: Maiolo, Pablo
# *   Alumno 3: Miglino, Diego

# %% [markdown]
# ---
# ## **PARTE 1** - Instalación y requisitos previos
#
# > Las prácticas han sido preparadas para poder realizarse en el entorno de trabajo de Google Colab. Sin embargo, esta plataforma presenta ciertas incompatibilidades a la hora de visualizar la renderización en gym. Por ello, para obtener estas visualizaciones, se deberá trasladar el entorno de trabajo a local. Por ello, el presente dosier presenta instrucciones para poder trabajar en ambos entornos. Siga los siguientes pasos para un correcto funcionamiento:
# 1.   **LOCAL:** Preparar el enviroment, siguiendo las intrucciones detalladas en la sección *1.1.Preparar enviroment*.
# 2.  **AMBOS:** Modificar las variables "mount" y "drive_mount" a la carpeta de trabajo en drive en el caso de estar en Colab, y ejecturar la celda *1.2.Localizar entorno de trabajo*.
# 3. **COLAB:** se deberá ejecutar las celdas correspondientes al montaje de la carpeta de trabajo en Drive. Esta corresponde a la sección *1.3.Montar carpeta de datos local*.
# 4.  **AMBOS:** Instalar las librerías necesarias, siguiendo la sección *1.4.Instalar librerías necesarias*.

# %% [markdown]
# ---
# ### 1.1. Preparar enviroment (solo local)
#
#
#
# > Para preparar el entorno de trabajo en local, se han seguido los siguientes pasos:
# 1. En Windows, puede ser necesario instalar las C++ Build Tools. Para ello, siga los siguientes pasos: https://towardsdatascience.com/how-to-install-openai-gym-in-a-windows-environment-338969e24d30.
# 2. Instalar Anaconda
# 3. Siguiendo el código que se presenta comentado en la próxima celda: Crear un enviroment, cambiar la ruta de trabajo, e instalar librerías básicas.
#
#
# ```
# conda create --name miar_rl python=3.8
# conda activate miar_rl
# cd "PATH_TO_FOLDER"
# conda install git
# pip install jupyter
# ```
#
#
# 4. Abrir la notebook con *jupyter-notebook*.
#
#
#
# ```
# jupyter-notebook
# ```

# %% [markdown]
# ---
# ### 1.2. Localizar entorno de trabajo: Google colab o local

# %%
# ATENCIÓN!! Modificar ruta relativa a la práctica si es distinta (drive_root)
mount='/content/gdrive'
drive_root = mount + "/My Drive/08_MIAR/actividades/TP_Grupal"
mount='./'

try:
  from google.colab import drive
  IN_COLAB=True
except:
  IN_COLAB=False
print(IN_COLAB)
# Out:
# False

# %% [markdown]
# ---
# ### 1.3. Montar carpeta de datos local (solo Colab)

# %%
# Switch to the directory on the Google Drive that you want to use
import os
if IN_COLAB:
  print("We're running Colab")

  if IN_COLAB:
    # Mount the Google Drive at mount
    print("Colab: mounting Google drive on ", mount)

    drive.mount(mount)

    # Create drive_root if it doesn't exist
    create_drive_root = True
    if create_drive_root:
      print("\nColab: making sure ", drive_root, " exists.")
      os.makedirs(drive_root, exist_ok=True)

    # Change to the directory
    print("\nColab: Changing directory to ", drive_root)
    # %cd $drive_root
# Verify we're in the correct working directory
-of-00001', 'apr_g9_dqn_SpaceInvaders-v0_weights_1440000.h5f.index', 'apr_g9_dqn_SpaceInvaders-v0_weights_1470000.h5f.data-00000-of-00001', 'apr_g9_dqn_SpaceInvaders-v0_weights_1470000.h5f.index', 'apr_g9_dqn_SpaceInvaders-v0_weights_150000.h5f.data-00000-of-00001', 'apr_g9_dqn_SpaceInvaders-v0_weights_150000.h5f.index', 'apr_g9_dqn_SpaceInvaders-v0_weights_1500000.h5f.data-00000-of-00001', 'apr_g9_dqn_SpaceInvaders-v0_weights_1500000.h5f.index', 'apr_g9_dqn_SpaceInvaders-v0_weights_1530000.h5f.data-00000-of-00001', 'apr_g9_dqn_SpaceInvaders-v0_weights_1530000.h5f.index', 'apr_g9_dqn_SpaceInvaders-v0_weights_1560000.h5f.data-00000-of-00001', 'apr_g9_dqn_SpaceInvaders-v0_weights_1560000.h5f.index', 'apr_g9_dqn_SpaceInvaders-v0_weights_1590000.h5f.data-00000-of-00001', 'apr_g9_dqn_SpaceInvaders-v0_weights_1590000.h5f.index', 'apr_g9_dqn_SpaceInvaders-v0_weights_1620000.h5f.data-00000-of-00001', 'apr_g9_dqn_SpaceInvaders-v0_weights_1620000.h5f.index', 'apr_g9_dqn_SpaceInvaders-v0_weights_1650000.h5f.data-00000-of-00001', 'apr_g9_dqn_SpaceInvaders-v0_weights_1650000.h5f.index', 'apr_g9_dqn_SpaceInvaders-v0_weights_1680000.h5f.data-00000-of-00001', 'apr_g9_dqn_SpaceInvaders-v0_weights_1680000.h5f.index', 'apr_g9_dqn_SpaceInvaders-v0_weights_1710000.h5f.data-00000-of-00001', 'apr_g9_dqn_SpaceInvaders-v0_weights_1710000.h5f.index', 'apr_g9_dqn_SpaceInvaders-v0_weights_1740000.h5f.data-00000-of-00001', 'apr_g9_dqn_SpaceInvaders-v0_weights_1740000.h5f.index', 'apr_g9_dqn_SpaceInvaders-v0_weights_1770000.h5f.data-00000-of-00001', 'apr_g9_dqn_SpaceInvaders-v0_weights_1770000.h5f.index', 'apr_g9_dqn_SpaceInvaders-v0_weights_180000.h5f.data-00000-of-00001', 'apr_g9_dqn_ ...

# %% [markdown]
# ---
# ### 1.4. Instalar librerías necesarias

# %%
# ejecutar solo la primera vez..

if IN_COLAB:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install keras-rl2==1.0.5
  # %pip install tensorflow==2.12
else:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install pyglet==1.5.0
  # %pip install h5py==3.1.0
  # %pip install Pillow==9.5.0
  # %pip install keras-rl2==1.0.5
  # %pip install Keras==2.2.4
  # %pip install tensorflow==2.5.3
  # %pip install torch==2.0.1
  # %pip install agents==1.4.0
  # %pip install matplotlib==3.3.4
# Out:
# Requirement already satisfied: gym==0.17.3 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (0.17.3)
# Requirement already satisfied: scipy in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from gym==0.17.3) (1.10.1)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from gym==0.17.3) (1.24.4)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from gym==0.17.3) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from gym==0.17.3) (1.6.0)
# Requirement already satisfied: future in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from pyglet<=1.5.0,>=1.4.0->gym==0.17.3) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting git+https://github.com/Kojoley/atari-py.git
#   Cloning https://github.com/Kojoley/atari-py.git to c:\users\dmigl\appdata\local\temp\pip-req-build-r02cc9bg
#   Resolved https://github.com/Kojoley/atari-py.git to commit 86a1e05c0a95e9e6233c3a413521fdb34ca8a089
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from atari-py==1.2.2) (1.24.4)
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/Kojoley/atari-py.git 'C:\Users\dmigl\AppData\Local\Temp\pip-req-build-r02cc9bg'
# Requirement already satisfied: pyglet==1.5.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (1.5.0)
# Requirement already satisfied: future in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from pyglet==1.5.0) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: h5py==3.1.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (3.1.0)
# Requirement already satisfied: numpy>=1.17.5 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from h5py==3.1.0) (1.24.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: Pillow==9.5.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (9.5.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: keras-rl2==1.0.5 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (1.0.5)
# Requirement already satisfied: tensorflow in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from keras-rl2==1.0.5) (2.5.3)
# Collecting numpy~=1.19.2 (from tensorflow->keras-rl2==1.0.5)
#   Using cached numpy-1.19.5-cp38-cp38-win_amd64.whl.metadata (2.0 kB)
# Requirement already satisfied: absl-py~=0.10 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->keras-rl2==1.0.5) (0.15.0)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->keras-rl2==1.0.5) (1.6.3)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->keras-rl2==1.0.5) (1.12)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->keras-rl2==1.0.5) (0.2.0)
# Requirement already satisfied: h5py~=3.1.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->keras-rl2==1.0.5) (3.1.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->keras-rl2==1.0.5) (1.1.2)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->keras-rl2==1.0.5) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->keras-rl2==1.0.5) (3.20.3)
# Requirement already satisfied: six~=1.15.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->keras-rl2==1.0.5) (1.15.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->keras-rl2==1.0.5) (1.1.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->keras-rl2==1.0.5) (3.7.4.3)
# Requirement already satisfied: wheel~=0.35 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->keras-rl2==1.0.5) (0.44.0)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->keras-rl2==1.0.5) (1.12.1)
# Requirement already satisfied: gast==0.4.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->keras-rl2==1.0.5) (0.4.0)
# Requirement already satisfied: tensorboard~=2.5 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->keras-rl2==1.0.5) (2.11.2)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->keras-rl2==1.0.5) (2.5.0)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->keras-rl2==1.0.5) (2.5.0.dev2021032900)
# Requirement already satisfied: grpcio~=1.34.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->keras-rl2==1.0.5) (1.34.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow->keras-rl2==1.0.5) (2.40.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow->keras-rl2==1.0.5) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow->keras-rl2==1.0.5) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow->keras-rl2==1.0.5) (2.32.4)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow->keras-rl2==1.0.5) (75.3.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow->keras-rl2==1.0.5) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow->keras-rl2==1.0.5) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow->keras-rl2==1.0.5) (3.0.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow->keras-rl2==1.0.5) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow->keras-rl2==1.0.5) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow->keras-rl2==1.0.5) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow->keras-rl2==1.0.5) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow->keras-rl2==1.0.5) (8.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->keras-rl2==1.0.5) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->keras-rl2==1.0.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->keras-rl2==1.0.5) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->keras-rl2==1.0.5) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.5->tensorflow->keras-rl2==1.0.5) (2.1.5)
# Requirement already satisfied: zipp>=3.20 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.5->tensorflow->keras-rl2==1.0.5) (3.20.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow->keras-rl2==1.0.5) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow->keras-rl2==1.0.5) (3.2.2)
# Using cached numpy-1.19.5-cp38-cp38-win_amd64.whl (13.3 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
# Successfully installed numpy-1.19.5
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'C:\Users\dmigl\anaconda3\envs\env_apr_g9\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Requirement already satisfied: Keras==2.2.4 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (2.2.4)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from Keras==2.2.4) (1.19.5)
# Requirement already satisfied: scipy>=0.14 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from Keras==2.2.4) (1.10.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from Keras==2.2.4) (1.15.0)
# Requirement already satisfied: pyyaml in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from Keras==2.2.4) (6.0.2)
# Requirement already satisfied: h5py in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from Keras==2.2.4) (3.1.0)
# Requirement already satisfied: keras-applications>=1.0.6 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from Keras==2.2.4) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from Keras==2.2.4) (1.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow==2.5.3 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (2.5.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy~=1.19.2 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow==2.5.3) (1.19.5)
# Requirement already satisfied: absl-py~=0.10 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow==2.5.3) (0.15.0)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow==2.5.3) (1.6.3)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow==2.5.3) (1.12)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow==2.5.3) (0.2.0)
# Requirement already satisfied: h5py~=3.1.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow==2.5.3) (3.1.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow==2.5.3) (1.1.2)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow==2.5.3) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow==2.5.3) (3.20.3)
# Requirement already satisfied: six~=1.15.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow==2.5.3) (1.15.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow==2.5.3) (1.1.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow==2.5.3) (3.7.4.3)
# Requirement already satisfied: wheel~=0.35 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow==2.5.3) (0.44.0)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow==2.5.3) (1.12.1)
# Requirement already satisfied: gast==0.4.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow==2.5.3) (0.4.0)
# Requirement already satisfied: tensorboard~=2.5 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow==2.5.3) (2.11.2)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow==2.5.3) (2.5.0)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow==2.5.3) (2.5.0.dev2021032900)
# Requirement already satisfied: grpcio~=1.34.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow==2.5.3) (1.34.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.3) (2.40.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.3) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.3) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.3) (2.32.4)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.3) (75.3.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.3) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.3) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.3) (3.0.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.3) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.3) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.3) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.3) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5.3) (8.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.3) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.3) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.3) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.5->tensorflow==2.5.3) (2.1.5)
# Requirement already satisfied: zipp>=3.20 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5.3) (3.20.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.3) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.3) (3.2.2)
# Requirement already satisfied: torch==2.0.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (2.0.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: filelock in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from torch==2.0.1) (3.16.1)
# Requirement already satisfied: typing-extensions in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from torch==2.0.1) (3.7.4.3)
# Requirement already satisfied: sympy in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from torch==2.0.1) (1.13.3)
# Requirement already satisfied: networkx in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from torch==2.0.1) (3.1)
# Requirement already satisfied: jinja2 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from torch==2.0.1) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from jinja2->torch==2.0.1) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from sympy->torch==2.0.1) (1.3.0)
# Requirement already satisfied: agents==1.4.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (1.4.0)
# Requirement already satisfied: tensorflow in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from agents==1.4.0) (2.5.3)
# Requirement already satisfied: gym in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from agents==1.4.0) (0.17.3)
# Requirement already satisfied: ruamel.yaml in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from agents==1.4.0) (0.18.14)
# Requirement already satisfied: scipy in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from gym->agents==1.4.0) (1.10.1)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from gym->agents==1.4.0) (1.19.5)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from gym->agents==1.4.0) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from gym->agents==1.4.0) (1.6.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from ruamel.yaml->agents==1.4.0) (0.2.8)
# Requirement already satisfied: absl-py~=0.10 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->agents==1.4.0) (0.15.0)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->agents==1.4.0) (1.6.3)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->agents==1.4.0) (1.12)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->agents==1.4.0) (0.2.0)
# Requirement already satisfied: h5py~=3.1.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->agents==1.4.0) (3.1.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->agents==1.4.0) (1.1.2)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->agents==1.4.0) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->agents==1.4.0) (3.20.3)
# Requirement already satisfied: six~=1.15.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->agents==1.4.0) (1.15.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->agents==1.4.0) (1.1.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->agents==1.4.0) (3.7.4.3)
# Requirement already satisfied: wheel~=0.35 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->agents==1.4.0) (0.44.0)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->agents==1.4.0) (1.12.1)
# Requirement already satisfied: gast==0.4.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->agents==1.4.0) (0.4.0)
# Requirement already satisfied: tensorboard~=2.5 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->agents==1.4.0) (2.11.2)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->agents==1.4.0) (2.5.0)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->agents==1.4.0) (2.5.0.dev2021032900)
# Requirement already satisfied: grpcio~=1.34.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorflow->agents==1.4.0) (1.34.1)
# Requirement already satisfied: future in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from pyglet<=1.5.0,>=1.4.0->gym->agents==1.4.0) (1.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow->agents==1.4.0) (2.40.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow->agents==1.4.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow->agents==1.4.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow->agents==1.4.0) (2.32.4)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow->agents==1.4.0) (75.3.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow->agents==1.4.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow->agents==1.4.0) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from tensorboard~=2.5->tensorflow->agents==1.4.0) (3.0.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow->agents==1.4.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow->agents==1.4.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow->agents==1.4.0) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow->agents==1.4.0) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow->agents==1.4.0) (8.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->agents==1.4.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->agents==1.4.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->agents==1.4.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->agents==1.4.0) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.5->tensorflow->agents==1.4.0) (2.1.5)
# Requirement already satisfied: zipp>=3.20 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.5->tensorflow->agents==1.4.0) (3.20.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow->agents==1.4.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow->agents==1.4.0) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ---
# ## **PARTE 2**. Enunciado
#
# Consideraciones a tener en cuenta:
#
# - El entorno sobre el que trabajaremos será _SpaceInvaders-v0_ y el algoritmo que usaremos será _DQN_.
#
# - Para nuestro ejercicio, el requisito mínimo será alcanzado cuando el agente consiga una **media de recompensa por encima de 20 puntos en modo test**. Por ello, esta media de la recompensa se calculará a partir del código de test en la última celda del notebook.
#
# Este proyecto práctico consta de tres partes:
#
# 1.   Implementar la red neuronal que se usará en la solución
# 2.   Implementar las distintas piezas de la solución DQN
# 3.   Justificar la respuesta en relación a los resultados obtenidos
#
# **Rúbrica**: Se valorará la originalidad en la solución aportada, así como la capacidad de discutir los resultados de forma detallada. El requisito mínimo servirá para aprobar la actividad, bajo premisa de que la discusión del resultado sera apropiada.
#
# IMPORTANTE:
#
# * Si no se consigue una puntuación óptima, responder sobre la mejor puntuación obtenida.
# * Para entrenamientos largos, recordad que podéis usar checkpoints de vuestros modelos para retomar los entrenamientos. En este caso, recordad cambiar los parámetros adecuadamente (sobre todo los relacionados con el proceso de exploración).
# * Se deberá entregar unicamente el notebook y los pesos del mejor modelo en un fichero .zip, de forma organizada.
# * Cada alumno deberá de subir la solución de forma individual.

# %% [markdown]
# ---
# ## **PARTE 3**. Desarrollo y preguntas

# %% [markdown]
# #### Importar librerías

# %%
from __future__ import division

from PIL import Image
import numpy as np
import gym

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Convolution2D, Permute, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.optimizers.schedules import ExponentialDecay
import tensorflow.keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

# %% [markdown]
# #### Configuración base

# %%
INPUT_SHAPE = (84, 84)
WINDOW_LENGTH = 4

env_name = 'SpaceInvaders-v0'
env = gym.make(env_name)

np.random.seed(123)
env.seed(123)
nb_actions = env.action_space.n

print("Numero de acciones disponibles: " + str(nb_actions) + " -> " + str(env.unwrapped.get_action_meanings()))
print("Formato de las observaciones: " + str(env.observation_space))
# Out:
# Numero de acciones disponibles: 6 -> ['NOOP', 'FIRE', 'RIGHT', 'LEFT', 'RIGHTFIRE', 'LEFTFIRE']
# Formato de las observaciones: Box(0, 255, (210, 160, 3), uint8)

# %%
class AtariProcessor(Processor):
    def process_observation(self, observation):
        assert observation.ndim == 3  # (height, width, channel)
        # removemos la parte superior (score) y inferior (vida del jugador)
        cropped = observation[20:200, 8:152]
        img = Image.fromarray(cropped)
        img = img.resize(INPUT_SHAPE, Image.LANCZOS).convert('L')
        processed_observation = np.array(img)
        assert processed_observation.shape == INPUT_SHAPE
        return processed_observation.astype('uint8')

    def process_state_batch(self, batch):
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        return np.clip(reward, -1., 1.)

# %%
from rl.callbacks import Callback
import numpy as np

class SaveBestRewardCallback(Callback):
    def __init__(self, env,
                 filename='best_model.h5f',
                 test_episodes=5,
                 test_interval=1000):
        self.env = env
        self.filename = filename
        self.test_episodes = test_episodes
        self.test_interval = test_interval
        self.best_reward = -np.inf
        self.steps_since_last_eval = 0

    def on_step_end(self, step, logs=None):
        self.steps_since_last_eval += 1

        if self.steps_since_last_eval >= self.test_interval:
            self.steps_since_last_eval = 0

            # --- congelar contador ---
            saved_step = self.model.step

            # --- evaluación ---
            history = self.model.test(
                self.env,
                nb_episodes=self.test_episodes,
                visualize=False,
                verbose=0
            )
            
            avg_reward = np.mean(history.history['episode_reward'])
            max_reward = np.max(history.history['episode_reward'])
            std_reward = np.std(history.history['episode_reward'])

            # --- restaurar contador ---
            self.model.step = saved_step

            print(f"\n>>> Evaluando Step {saved_step} -> Avg={avg_reward:.2f}, Max={max_reward:.2f}, Std={std_reward:.2f} -> {history.history['episode_reward']}")

            if avg_reward > self.best_reward:
                self.best_reward = avg_reward
                self.model.save_weights(self.filename, overwrite=True)
                print(f">>> Nuevo récord: {avg_reward:.2f} -> Guardado en {self.filename}")

# %%
from rl.callbacks import Callback

class PERMonitorCallback(Callback):
    """Callback para monitorear el estado de Prioritized Experience Replay"""
    
    def __init__(self, interval=5000):
        self.interval = interval
        self.steps_since_log = 0
        
    def on_step_end(self, step, logs=None):
        self.steps_since_log += 1
        if self.steps_since_log >= self.interval:
            self.steps_since_log = 0
            
            # Verificar si tenemos una memoria PER
            memory = self.model.memory
            if hasattr(memory, 'beta_by_frame'):
                current_beta = memory.beta_by_frame(memory.frame_idx)
                memory_size = len(memory)
                max_priority = memory.max_priority
                tree_total = memory.tree.total() if hasattr(memory, 'tree') else 0
                
                print(f"\n>>> PER Stats (Step {step}):")
                print(f"    Beta: {current_beta:.4f}")
                print(f"    Memory size: {memory_size}")
                print(f"    Max priority: {max_priority:.4f}")
                print(f"    Tree total: {tree_total:.2f}")
            else:
                print(f"\n>>> Memory Stats (Step {step}):")
                print(f"    Memory size: {len(memory)}")
                print(f"    Memory type: {type(memory).__name__}")

    def on_episode_end(self, episode, logs=None):
        """Opcionalmente mostrar stats al final del episodio"""
        pass

# %%
import tensorflow as tf

print("Versión de TensorFlow:", tf.__version__)
gpus = tf.config.experimental.list_physical_devices('GPU')
print(gpus)

if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    print("GPU detectada:", gpus[0])
else:
    print("No se detectó GPU")
# Out:
# Versión de TensorFlow: 2.5.3
# []
# No se detectó GPU

# %% [markdown]
# 1. Implementación de la red neuronal

# %%
# modelo mas complejo - usar este
input_shape = (WINDOW_LENGTH,) + INPUT_SHAPE
model = Sequential()
print(K.image_data_format())
print(input_shape)

if K.image_data_format() == 'channels_last':
    # (width, height, channels)
    model.add(Permute((2, 3, 1), input_shape=input_shape))
elif K.image_data_format() == 'channels_first':
    # (channels, width, height)
    model.add(Permute((1, 2, 3), input_shape=input_shape))
else:
    raise RuntimeError('Unknown image_dim_ordering.')

# Capas convolucionales mejoradas con inicialización HeNormal
model.add(Convolution2D(32, (8, 8), strides=(4, 4), 
                       activation='relu', kernel_initializer=HeNormal()))
 # model.add(BatchNormalization())

model.add(Convolution2D(64, (4, 4), strides=(2, 2), 
                       activation='relu', kernel_initializer=HeNormal()))
 # model.add(BatchNormalization())

model.add(Convolution2D(64, (3, 3), strides=(1, 1), 
                       activation='relu', kernel_initializer=HeNormal()))
 # model.add(BatchNormalization())

model.add(Flatten())

# Capas densas con dropout y batch normalization
model.add(Dense(512, activation='relu', kernel_initializer=HeNormal()))
 # model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Dense(256, activation='relu', kernel_initializer=HeNormal()))
 # model.add(BatchNormalization())
model.add(Dropout(0.2))

# Capa de salida
model.add(Dense(nb_actions, activation='linear', kernel_initializer=HeNormal()))

print(model.summary())
# Out:
# channels_last
# (4, 84, 84)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# permute (Permute)            (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 20, 20, 32)        8224
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 9, 9, 64)          32832
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1606144
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 1542
# =================================================================
# Total params: 1,816,998
# Trainable params: 1,816,998
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# 2. Implementación de la solución DQN

# %%
import numpy as np
import random
from collections import deque
from rl.memory import Memory
import warnings

class SumTree:
    """
    Estructura de datos Sum Tree para muestreo eficiente basado en prioridades.
    """
    def __init__(self, capacity):
        self.capacity = capacity
        self.tree = np.zeros(2 * capacity - 1)
        self.data = np.zeros(capacity, dtype=object)
        self.n_entries = 0
        self.pending_idx = set()

    def _propagate(self, idx, change):
        """Propaga el cambio hacia arriba en el árbol"""
        parent = (idx - 1) // 2
        self.tree[parent] += change
        if parent != 0:
            self._propagate(parent, change)

    def _retrieve(self, idx, s):
        """Recupera el índice de la hoja correspondiente al valor s"""
        left = 2 * idx + 1
        right = left + 1

        if left >= len(self.tree):
            return idx

        if s <= self.tree[left]:
            return self._retrieve(left, s)
        else:
            return self._retrieve(right, s - self.tree[left])

    def total(self):
        """Retorna la suma total (raíz del árbol)"""
        return self.tree[0]

    def add(self, p, data):
        """Añade una nueva experiencia con prioridad p"""
        idx = self.n_entries + self.capacity - 1
        self.pending_idx.add(self.n_entries)
        
        self.data[self.n_entries] = data
        self.update(idx, p)

        self.n_entries += 1
        if self.n_entries >= self.capacity:
            self.n_entries = 0

    def update(self, idx, p):
        """Actualiza la prioridad en el índice idx"""
        change = p - self.tree[idx]
        self.tree[idx] = p
        self._propagate(idx, change)

    def get(self, s):
        """Obtiene una muestra basada en el valor s"""
        idx = self._retrieve(0, s)
        dataIdx = idx - self.capacity + 1
        self.pending_idx.discard(dataIdx)
        return (idx, self.tree[idx], self.data[dataIdx])


class PrioritizedExperienceReplay(Memory):
    """
    Implementación de Prioritized Experience Replay compatible con Keras-RL
    """
    def __init__(self, limit, alpha=0.6, beta_start=0.4, beta_frames=100000, 
                 epsilon=1e-6, window_length=1, ignore_episode_boundaries=False):
        super(PrioritizedExperienceReplay, self).__init__(window_length, ignore_episode_boundaries)
        
        self.limit = limit
        self.alpha = alpha  # Cuánto usar priorización (0 = uniforme, 1 = completamente priorizado)
        self.beta_start = beta_start  # Corrección de importancia inicial
        self.beta_frames = beta_frames  # Frames para llegar a beta=1.0
        self.epsilon = epsilon  # Pequeña cantidad para evitar prioridades cero
        self.frame_idx = 0  # Contador de frames para beta annealing
        
        # Estructuras de datos
        self.tree = SumTree(limit)
        self.experiences = deque(maxlen=limit)
        self.max_priority = 1.0
        
        # Para compatibilidad con keras-rl
        self.recent_observations = deque(maxlen=window_length)
        self.recent_actions = deque(maxlen=window_length)
        self.recent_rewards = deque(maxlen=window_length)
        self.recent_terminals = deque(maxlen=window_length)
        
    def beta_by_frame(self, frame_idx):
        """Annealing de beta desde beta_start hasta 1.0"""
        return min(1.0, self.beta_start + frame_idx * (1.0 - self.beta_start) / self.beta_frames)
    
    def append(self, observation, action, reward, terminal, training=True):
        """Añade una experiencia a la memoria"""
        super(PrioritizedExperienceReplay, self).append(observation, action, reward, terminal, training)
        
        if training:
            # Solo crear experiencia si tenemos al menos una observación previa
            if len(self.recent_observations) >= 2:
                # Crear la experiencia
                experience = {
                    'observation0': self.recent_observations[-2],  # Observación anterior
                    'action': action, 
                    'reward': reward,
                    'observation1': observation,  # Observación actual
                    'terminal1': terminal,
                }
                
                # Añadir con prioridad máxima (para nuevas experiencias)
                priority = self.max_priority ** self.alpha
                self.tree.add(priority, experience)
                self.experiences.append(experience)
            elif len(self.recent_observations) == 1:
                # Para la primera experiencia, usar la misma observación
                experience = {
                    'observation0': self.recent_observations[-1],
                    'action': action,
                    'reward': reward, 
                    'observation1': observation,
                    'terminal1': terminal,
                }
                
                priority = self.max_priority ** self.alpha
                self.tree.add(priority, experience)
                self.experiences.append(experience)
    
    def sample(self, batch_size, batch_idxs=None):
        """Muestrea un batch de experiencias basado en prioridades"""
        if batch_idxs is not None:
            warnings.warn('PrioritizedExperienceReplay ignora batch_idxs')
        
        if len(self.experiences) == 0:
            raise ValueError('No hay experiencias para muestrear')
        
        # Inicializar listas para el batch
        batch = []
        idxs = []
        priorities = []
        
        # Muestreo basado en prioridades
        beta = self.beta_by_frame(self.frame_idx)
        self.frame_idx += 1
        
        if self.tree.total() == 0 or len(self.experiences) < batch_size:
            # Muestreo uniforme si el árbol está vacío o no hay suficientes experiencias
            for i in range(batch_size):
                idx = random.randint(0, len(self.experiences) - 1)
                batch.append(self.experiences[idx])
                idxs.append(idx)
                priorities.append(self.max_priority)
        else:
            # Muestreo normal basado en prioridades
            segment = self.tree.total() / batch_size
            
            for i in range(batch_size):
                a = segment * i
                b = segment * (i + 1)
                s = random.uniform(a, b)
                
                try:
                    (idx, p, data) = self.tree.get(s)
                    if data is not None:
                        batch.append(data)
                        idxs.append(idx)
                        priorities.append(p)
                    else:
                        # Fallback si no se puede obtener data
                        fallback_idx = random.randint(0, len(self.experiences) - 1)
                        batch.append(self.experiences[fallback_idx])
                        idxs.append(fallback_idx)
                        priorities.append(self.max_priority)
                except:
                    # Fallback en caso de error
                    fallback_idx = random.randint(0, len(self.experiences) - 1)
                    batch.append(self.experiences[fallback_idx])
                    idxs.append(fallback_idx)
                    priorities.append(self.max_priority)
        
        # Calcular pesos de importancia
        if self.tree.total() > 0:
            sampling_probabilities = np.array(priorities) / self.tree.total()
            is_weight = np.power(len(self.experiences) * sampling_probabilities, -beta)
            is_weight /= is_weight.max()  # Normalizar
        else:
            is_weight = np.ones(batch_size)
        
        # Formatear batch para keras-rl con dimensiones correctas
        experiences = []
        for exp in batch:
            # Asegurar que las observaciones tengan la dimensión correcta
            state0 = exp['observation0']
            state1 = exp['observation1']
            
            # Si las observaciones no tienen la dimensión del window_length, agregarla
            if len(state0.shape) == 2:  # (height, width) -> (window_length, height, width)
                state0 = np.expand_dims(state0, axis=0)
            if len(state1.shape) == 2:  # (height, width) -> (window_length, height, width)
                state1 = np.expand_dims(state1, axis=0)
            
            # Si window_length > 1, repetir la observación para llenar la ventana
            if self.window_length > 1:
                if state0.shape[0] < self.window_length:
                    state0 = np.repeat(state0, self.window_length, axis=0)[:self.window_length]
                if state1.shape[0] < self.window_length:
                    state1 = np.repeat(state1, self.window_length, axis=0)[:self.window_length]
            
            # Crear un objeto Experience compatible con keras-rl
            experience_obj = type('Experience', (), {
                'state0': state0,
                'action': exp['action'],
                'reward': exp['reward'],
                'state1': state1,
                'terminal1': exp['terminal1']
            })()
            experiences.append(experience_obj)
        
        # Almacenar información adicional para PER
        self._last_batch_idxs = idxs
        self._last_batch_priorities = priorities
        self._last_batch_weights = is_weight

        print("fSe seleccionaron estas experiencias del buffer: {experiences}")
        return experiences
    
    def update_priorities(self, batch_idxs, batch_priorities):
        """Actualiza las prioridades de las experiencias muestreadas"""
        for idx, priority in zip(batch_idxs, batch_priorities):
            priority = abs(priority) + self.epsilon  # Evitar prioridades cero
            self.max_priority = max(self.max_priority, priority)
            
            clipped_priority = priority ** self.alpha
            self.tree.update(idx, clipped_priority)
    
    def get_last_batch_info(self):
        """Retorna información del último batch muestreado para actualizar prioridades"""
        return {
            'idxs': getattr(self, '_last_batch_idxs', []),
            'priorities': getattr(self, '_last_batch_priorities', []),
            'weights': getattr(self, '_last_batch_weights', [])
        }
    
    def __len__(self):
        """Retorna el número de experiencias almacenadas"""
        return len(self.experiences)
    
    @property
    def nb_entries(self):
        """Propiedad para compatibilidad con keras-rl"""
        return len(self.experiences)

# %%
from tensorflow.keras.optimizers.schedules import ExponentialDecay

# memoria para almacenar la experiencia del agente
# memory = SequentialMemory(limit=10000, window_length=WINDOW_LENGTH)
# memory = EpisodeParameterMemory(limit=100000, window_length=WINDOW_LENGTH)
# memory = PrioritizedMemory(limit=100000, alpha=.6, start_beta=.4, end_beta=1., steps_annealed=100000, window_length=WINDOW_LENGTH)

# Memoria con priorizacion de mejores episodios 
memory = PrioritizedExperienceReplay(
    limit=3000000,           # Tamaño de memoria
    alpha=0.75,              # Priorización: 0.6 es un buen balance
    beta_start=0.4,         # Importance sampling inicial
    beta_frames=2500000,     # Frames para annealing (75% del entrenamiento)
    epsilon=1e-6,           # Evitar prioridades cero
    window_length=WINDOW_LENGTH,
    ignore_episode_boundaries=False
)
print(f"Prioritized Experience Replay configurado: alpha={memory.alpha}, beta_start={memory.beta_start}")

# processor
processor = AtariProcessor()

# policy que el agente va a seguir
#policy = BoltzmannQPolicy()
policy = LinearAnnealedPolicy(EpsGreedyQPolicy(), attr='eps',
                              value_max=1.00, value_min=0.1, 
                              value_test=.05, nb_steps=2500000)
print(f"Estrategia configurada: value_max={policy.value_max}, value_min={policy.value_min}, nb_steps={policy.nb_steps}")

# definicion del agente
dqn = DQNAgent(model=model, nb_actions=nb_actions, policy=policy,
               memory=memory, processor=processor,
               nb_steps_warmup=200000, gamma=.99,
               target_model_update=20000, train_interval=4, delta_clip=1.0,
               enable_double_dqn=True, enable_dueling_network=False)
print(f"Agente configurado: nb_steps_warmup={dqn.nb_steps_warmup}, gamma={dqn.gamma}, target_model_update={dqn.target_model_update}")

# compilacion del agente
initial_learning_rate = 0.0001  # Learning rate más conservador
lr_schedule = ExponentialDecay(
    initial_learning_rate,
    decay_steps=2500000,
    decay_rate=0.96,
    staircase=True
)
dqn.compile(Adam(learning_rate=lr_schedule), metrics=['mae'])
print(f"Learning Rate configurado: initial_lr={initial_learning_rate}, decay_rate={lr_schedule.decay_rate}, decay_steps={lr_schedule.decay_steps}")
# Out:
# Prioritized Experience Replay configurado: alpha=0.75, beta_start=0.4
# Estrategia configurada: value_max=1.0, value_min=0.1, nb_steps=2500000
# Agente configurado: nb_steps_warmup=200000, gamma=0.99, target_model_update=20000
# Learning Rate configurado: initial_lr=0.0001, decay_rate=0.96, decay_steps=2500000

# %%
# entrenamiento del agent
#weights_filename = 'apr_g9_dqn_{}_weights.h5f'.format(env_name)
checkpoint_weights_filename = 'apr_g9_dqn_' + env_name + '_weights_{step}_4M.h5f'
log_filename = 'apr_g9_dqn_{}_4M_log.json'.format(env_name)
callbacks = [
            ModelIntervalCheckpoint(checkpoint_weights_filename, interval=40000),
            FileLogger(log_filename, interval=40000),
            SaveBestRewardCallback(env, filename='best_model_weights_4M.h5f', test_episodes=5, test_interval=40000),
            PERMonitorCallback(interval=40000) ]
entrenamiento = dqn.fit(env, callbacks=callbacks, nb_steps=4000000, log_interval=20000, visualize=False, verbose=1)

# se graban los pesos finales luego de finalizar el entrenamiento
#dqn.save_weights('apr_g9_dqn_{}_weights.h5f'.format(env_name), overwrite=True)
# Out:
# Training for 4000000 steps ...
# Interval 1 (0 steps performed)
#    33/20000 [..............................] - ETA: 1:04 - reward: 0.0000e+00
# C:\Users\dmigl\anaconda3\envs\env_apr_g9\lib\site-packages\tensorflow\python\keras\engine\training.py:2424: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 20000/20000 [==============================] - 56s 3ms/step - reward: 0.0140
# 30 episodes - episode_reward: 9.133 [3.000, 24.000] - ale.lives: 2.029
#
# Interval 2 (20000 steps performed)
# 19984/20000 [============================>.] - ETA: 0s - reward: 0.0141
# >>> Evaluando Step 39999 -> Avg=16.20, Max=30.00, Std=8.57 -> [21.0, 5.0, 13.0, 30.0, 12.0]
# >>> Nuevo récord: 16.20 -> Guardado en best_model_weights_4M.h5f
#
# >>> PER Stats (Step 414):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 65s 3ms/step - reward: 0.0140
# 27 episodes - episode_reward: 10.481 [3.000, 23.000] - ale.lives: 2.123
#
# Interval 3 (40000 steps performed)
# 20000/20000 [==============================] - 54s 3ms/step - reward: 0.0199
# 27 episodes - episode_reward: 14.593 [5.000, 33.000] - ale.lives: 2.047
#
# Interval 4 (60000 steps performed)
# 19989/20000 [============================>.] - ETA: 0s - reward: 0.0204
# >>> Evaluando Step 79999 -> Avg=24.40, Max=44.00, Std=10.46 -> [44.0, 16.0, 16.0, 26.0, 20.0]
# >>> Nuevo récord: 24.40 -> Guardado en best_model_weights_4M.h5f
#
# >>> PER Stats (Step 781):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 70s 3ms/step - reward: 0.0204
# 24 episodes - episode_reward: 16.792 [6.000, 28.000] - ale.lives: 2.044
#
# Interval 5 (80000 steps performed)
# 20000/20000 [==============================] - 52s 3ms/step - reward: 0.0204
# 27 episodes - episode_reward: 15.185 [5.000, 28.000] - ale.lives: 2.050
#
# Interval 6 (100000 steps performed)
# 19991/20000 [============================>.] - ETA: 0s - reward: 0.0205
# >>> Evaluando Step 119999 -> Avg=16.20, Max=21.00, Std=3.43 -> [21.0, 18.0, 17.0, 14.0, 11.0]
#
# >>> PER Stats (Step 319):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 63s 3ms/step - reward: 0.0205
# 26 episodes - episode_reward: 15.923 [6.000, 32.000] - ale.lives: 2.042
#
# Interval 7 (120000 steps performed)
# 20000/20000 [==============================] - 54s 3ms/step - reward: 0.0191
# 24 episodes - episode_reward: 15.625 [5.000, 27.000] - ale.lives: 2.056
#
# Interval 8 (140000 steps performed)
# 19991/20000 [============================>.] - ETA: 0s - reward: 0.0213
# >>> Evaluando Step 159999 -> Avg=14.20, Max=22.00, Std=7.83 -> [7.0, 3.0, 17.0, 22.0, 22.0]
#
# >>> PER Stats (Step 534):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 63s 3ms/step - reward: 0.0213
# 26 episodes - episode_reward: 16.462 [6.000, 28.000] - ale.lives: 2.024
#
# Interval 9 (160000 steps performed)
# 20000/20000 [==============================] - 53s 3ms/step - reward: 0.0188
# 26 episodes - episode_reward: 14.923 [9.000, 21.000] - ale.lives: 1.975
#
# Interval 10 (180000 steps performed)
# 19997/20000 [============================>.] - ETA: 0s - reward: 0.0211
# >>> Evaluando Step 199999 -> Avg=20.00, Max=28.00, Std=6.10 -> [23.0, 28.0, 10.0, 17.0, 22.0]
#
# >>> PER Stats (Step 537):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 62s 3ms/step - reward: 0.0210
# 25 episodes - episode_reward: 16.320 [4.000, 31.000] - ale.lives: 2.119
#
# Interval 11 (200000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0209
# 23 episodes - episode_reward: 17.913 [4.000, 52.000] - ale.lives: 2.059
#
# Interval 12 (220000 steps performed)
# 19987/20000 [============================>.] - ETA: 0s - reward: 0.0203
# >>> Evaluando Step 239999 -> Avg=16.20, Max=24.00, Std=4.40 -> [12.0, 13.0, 18.0, 24.0, 14.0]
#
# >>> PER Stats (Step 1205):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 58s 3ms/step - reward: 0.0203
# 23 episodes - episode_reward: 17.478 [9.000, 32.000] - ale.lives: 1.948
#
# Interval 13 (240000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0195
# 24 episodes - episode_reward: 16.792 [8.000, 26.000] - ale.lives: 1.950
#
# Interval 14 (260000 steps performed)
# 19990/20000 [============================>.] - ETA: 0s - reward: 0.0199
# >>> Evaluando Step 279999 -> Avg=17.00, Max=25.00, Std=5.97 -> [13.0, 25.0, 18.0, 8.0, 21.0]
#
# >>> PER Stats (Step 958):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 58s 3ms/step - reward: 0.0199
# 24 episodes - episode_reward: 16.000 [7.000, 27.000] - ale.lives: 2.032
#
# Interval 15 (280000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0200
# 24 episodes - episode_reward: 17.042 [7.000, 30.000] - ale.lives: 2.002
#
# Interval 16 (300000 steps performed)
# 19993/20000 [============================>.] - ETA: 0s - reward: 0.0213
# >>> Evaluando Step 319999 -> Avg=17.00, Max=31.00, Std=7.29 -> [16.0, 31.0, 15.0, 10.0, 13.0]
#
# >>> PER Stats (Step 359):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 58s 3ms/step - reward: 0.0213
# 27 episodes - episode_reward: 16.074 [8.000, 24.000] - ale.lives: 2.022
#
# Interval 17 (320000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0204
# 27 episodes - episode_reward: 15.296 [7.000, 30.000] - ale.lives: 2.068
#
# Interval 18 (340000 steps performed)
# 19981/20000 [============================>.] - ETA: 0s - reward: 0.0219
# >>> Evaluando Step 359999 -> Avg=16.40, Max=24.00, Std=4.96 -> [15.0, 24.0, 19.0, 9.0, 15.0]
#
# >>> PER Stats (Step 641):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 57s 3ms/step - reward: 0.0220
# 23 episodes - episode_reward: 18.478 [10.000, 30.000] - ale.lives: 1.966
#
# Interval 19 (360000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0208
# 24 episodes - episode_reward: 17.417 [9.000, 31.000] - ale.lives: 2.088
#
# Interval 20 (380000 steps performed)
# 19999/20000 [============================>.] - ETA: 0s - reward: 0.0211
# >>> Evaluando Step 399999 -> Avg=19.20, Max=29.00, Std=7.30 -> [16.0, 25.0, 8.0, 18.0, 29.0]
#
# >>> PER Stats (Step 317):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0211
# 25 episodes - episode_reward: 17.200 [5.000, 30.000] - ale.lives: 2.101
#
# Interval 21 (400000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0198
# 26 episodes - episode_reward: 15.462 [6.000, 26.000] - ale.lives: 1.914
#
# Interval 22 (420000 steps performed)
# 19979/20000 [============================>.] - ETA: 0s - reward: 0.0213
# >>> Evaluando Step 439999 -> Avg=16.20, Max=25.00, Std=5.42 -> [18.0, 17.0, 25.0, 10.0, 11.0]
#
# >>> PER Stats (Step 1216):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 58s 3ms/step - reward: 0.0213
# 25 episodes - episode_reward: 15.800 [7.000, 28.000] - ale.lives: 2.097
#
# Interval 23 (440000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0208
# 26 episodes - episode_reward: 17.038 [5.000, 36.000] - ale.lives: 1.983
#
# Interval 24 (460000 steps performed)
# 19982/20000 [============================>.] - ETA: 0s - reward: 0.0191
# >>> Evaluando Step 479999 -> Avg=17.60, Max=24.00, Std=4.84 -> [18.0, 21.0, 15.0, 10.0, 24.0]
#
# >>> PER Stats (Step 500):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0191
# 26 episodes - episode_reward: 14.346 [6.000, 25.000] - ale.lives: 2.011
#
# Interval 25 (480000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0203
# 23 episodes - episode_reward: 17.391 [3.000, 36.000] - ale.lives: 2.130
#
# Interval 26 (500000 steps performed)
# 19977/20000 [============================>.] - ETA: 0s - reward: 0.0210
# >>> Evaluando Step 519999 -> Avg=12.80, Max=24.00, Std=5.71 -> [11.0, 11.0, 8.0, 10.0, 24.0]
#
# >>> PER Stats (Step 447):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 55s 3ms/step - reward: 0.0210
# 25 episodes - episode_reward: 17.120 [7.000, 28.000] - ale.lives: 1.974
#
# Interval 27 (520000 steps performed)
# 20000/20000 [==============================] - 47s 2ms/step - reward: 0.0205
# 24 episodes - episode_reward: 17.125 [5.000, 32.000] - ale.lives: 2.025
#
# Interval 28 (540000 steps performed)
# 19989/20000 [============================>.] - ETA: 0s - reward: 0.0203
# >>> Evaluando Step 559999 -> Avg=15.00, Max=19.00, Std=3.79 -> [9.0, 19.0, 15.0, 13.0, 19.0]
#
# >>> PER Stats (Step 230):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 54s 3ms/step - reward: 0.0203
# 26 episodes - episode_reward: 15.654 [4.000, 30.000] - ale.lives: 2.043
#
# Interval 29 (560000 steps performed)
# 20000/20000 [==============================] - 47s 2ms/step - reward: 0.0209
# 25 episodes - episode_reward: 16.480 [6.000, 30.000] - ale.lives: 2.098
#
# Interval 30 (580000 steps performed)
# 19976/20000 [============================>.] - ETA: 0s - reward: 0.0214
# >>> Evaluando Step 599999 -> Avg=14.60, Max=27.00, Std=7.39 -> [10.0, 27.0, 19.0, 10.0, 7.0]
#
# >>> PER Stats (Step 586):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 54s 3ms/step - reward: 0.0214
# 24 episodes - episode_reward: 17.667 [7.000, 33.000] - ale.lives: 2.090
#
# Interval 31 (600000 steps performed)
# 20000/20000 [==============================] - 46s 2ms/step - reward: 0.0188
# 24 episodes - episode_reward: 16.250 [2.000, 33.000] - ale.lives: 2.102
#
# Interval 32 (620000 steps performed)
# 19982/20000 [============================>.] - ETA: 0s - reward: 0.0208
# >>> Evaluando Step 639999 -> Avg=20.20, Max=26.00, Std=4.26 -> [17.0, 21.0, 26.0, 23.0, 14.0]
#
# >>> PER Stats (Step 635):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 57s 3ms/step - reward: 0.0209
# 25 episodes - episode_reward: 16.160 [7.000, 32.000] - ale.lives: 2.082
#
# Interval 33 (640000 steps performed)
# 20000/20000 [==============================] - 47s 2ms/step - reward: 0.0220
# 26 episodes - episode_reward: 17.154 [8.000, 27.000] - ale.lives: 2.112
#
# Interval 34 (660000 steps performed)
# 19989/20000 [============================>.] - ETA: 0s - reward: 0.0184
# >>> Evaluando Step 679999 -> Avg=16.60, Max=20.00, Std=2.42 -> [20.0, 14.0, 15.0, 19.0, 15.0]
#
# >>> PER Stats (Step 536):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 56s 3ms/step - reward: 0.0184
# 24 episodes - episode_reward: 15.250 [5.000, 26.000] - ale.lives: 2.081
#
# Interval 35 (680000 steps performed)
# 20000/20000 [==============================] - 47s 2ms/step - reward: 0.0202
# 27 episodes - episode_reward: 14.593 [2.000, 34.000] - ale.lives: 2.074
#
# Interval 36 (700000 steps performed)
# 19994/20000 [============================>.] - ETA: 0s - reward: 0.0208
# >>> Evaluando Step 719999 -> Avg=15.20, Max=23.00, Std=6.05 -> [9.0, 12.0, 10.0, 22.0, 23.0]
#
# >>> PER Stats (Step 924):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 55s 3ms/step - reward: 0.0208
# 26 episodes - episode_reward: 15.962 [8.000, 27.000] - ale.lives: 2.136
#
# Interval 37 (720000 steps performed)
# 20000/20000 [==============================] - 47s 2ms/step - reward: 0.0200
# 24 episodes - episode_reward: 17.208 [7.000, 33.000] - ale.lives: 2.072
#
# Interval 38 (740000 steps performed)
# 19986/20000 [============================>.] - ETA: 0s - reward: 0.0198
# >>> Evaluando Step 759999 -> Avg=17.80, Max=26.00, Std=5.88 -> [26.0, 10.0, 14.0, 16.0, 23.0]
#
# >>> PER Stats (Step 666):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 58s 3ms/step - reward: 0.0198
# 26 episodes - episode_reward: 15.154 [2.000, 29.000] - ale.lives: 2.010
#
# Interval 39 (760000 steps performed)
# 20000/20000 [==============================] - 47s 2ms/step - reward: 0.0198
# 24 episodes - episode_reward: 16.917 [7.000, 31.000] - ale.lives: 2.104
#
# Interval 40 (780000 steps performed)
# 19992/20000 [============================>.] - ETA: 0s - reward: 0.0212
# >>> Evaluando Step 799999 -> Avg=15.20, Max=24.00, Std=8.28 -> [20.0, 20.0, 11.0, 1.0, 24.0]
#
# >>> PER Stats (Step 8):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 56s 3ms/step - reward: 0.0211
# 22 episodes - episode_reward: 19.318 [10.000, 30.000] - ale.lives: 1.994
#
# Interval 41 (800000 steps performed)
# 20000/20000 [==============================] - 47s 2ms/step - reward: 0.0209
# 26 episodes - episode_reward: 16.000 [0.000, 34.000] - ale.lives: 2.012
#
# Interval 42 (820000 steps performed)
# 19981/20000 [============================>.] - ETA: 0s - reward: 0.0209
# >>> Evaluando Step 839999 -> Avg=14.60, Max=22.00, Std=4.59 -> [14.0, 17.0, 11.0, 22.0, 9.0]
#
# >>> PER Stats (Step 416):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 55s 3ms/step - reward: 0.0209
# 26 episodes - episode_reward: 15.846 [7.000, 34.000] - ale.lives: 1.886
#
# Interval 43 (840000 steps performed)
# 20000/20000 [==============================] - 48s 2ms/step - reward: 0.0197
# 23 episodes - episode_reward: 17.304 [6.000, 32.000] - ale.lives: 2.016
#
# Interval 44 (860000 steps performed)
# 19984/20000 [============================>.] - ETA: 0s - reward: 0.0214
# >>> Evaluando Step 879999 -> Avg=18.40, Max=24.00, Std=3.56 -> [24.0, 21.0, 15.0, 15.0, 17.0]
#
# >>> PER Stats (Step 1275):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 58s 3ms/step - reward: 0.0214
# 22 episodes - episode_reward: 18.182 [8.000, 30.000] - ale.lives: 1.968
#
# Interval 45 (880000 steps performed)
# 20000/20000 [==============================] - 48s 2ms/step - reward: 0.0207
# 25 episodes - episode_reward: 17.360 [4.000, 31.000] - ale.lives: 2.031
#
# Interval 46 (900000 steps performed)
# 19995/20000 [============================>.] - ETA: 0s - reward: 0.0208
# >>> Evaluando Step 919999 -> Avg=18.20, Max=25.00, Std=4.26 -> [14.0, 21.0, 14.0, 17.0, 25.0]
#
# >>> PER Stats (Step 208):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 58s 3ms/step - reward: 0.0209
# 24 episodes - episode_reward: 17.542 [8.000, 32.000] - ale.lives: 2.022
#
# Interval 47 (920000 steps performed)
# 20000/20000 [==============================] - 48s 2ms/step - reward: 0.0211
# 25 episodes - episode_reward: 16.800 [6.000, 32.000] - ale.lives: 2.159
#
# Interval 48 (940000 steps performed)
# 19986/20000 [============================>.] - ETA: 0s - reward: 0.0211
# >>> Evaluando Step 959999 -> Avg=16.00, Max=20.00, Std=3.03 -> [20.0, 11.0, 15.0, 18.0, 16.0]
#
# >>> PER Stats (Step 43):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 56s 3ms/step - reward: 0.0211
# 25 episodes - episode_reward: 17.200 [7.000, 30.000] - ale.lives: 1.926
#
# Interval 49 (960000 steps performed)
# 20000/20000 [==============================] - 48s 2ms/step - reward: 0.0206
# 25 episodes - episode_reward: 15.840 [0.000, 33.000] - ale.lives: 2.090
#
# Interval 50 (980000 steps performed)
# 19978/20000 [============================>.] - ETA: 0s - reward: 0.0197
# >>> Evaluando Step 999999 -> Avg=15.60, Max=23.00, Std=5.75 -> [20.0, 17.0, 10.0, 23.0, 8.0]
#
# >>> PER Stats (Step 819):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 56s 3ms/step - reward: 0.0197
# 26 episodes - episode_reward: 15.077 [1.000, 32.000] - ale.lives: 2.026
#
# Interval 51 (1000000 steps performed)
# 20000/20000 [==============================] - 48s 2ms/step - reward: 0.0198
# 27 episodes - episode_reward: 15.370 [5.000, 32.000] - ale.lives: 1.970
#
# Interval 52 (1020000 steps performed)
# 19997/20000 [============================>.] - ETA: 0s - reward: 0.0216
# >>> Evaluando Step 1039999 -> Avg=20.40, Max=32.00, Std=7.50 -> [32.0, 10.0, 17.0, 18.0, 25.0]
#
# >>> PER Stats (Step 683):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 58s 3ms/step - reward: 0.0215
# 25 episodes - episode_reward: 16.640 [7.000, 31.000] - ale.lives: 2.033
#
# Interval 53 (1040000 steps performed)
# 20000/20000 [==============================] - 48s 2ms/step - reward: 0.0209
# 24 episodes - episode_reward: 17.708 [3.000, 30.000] - ale.lives: 2.125
#
# Interval 54 (1060000 steps performed)
# 19982/20000 [============================>.] - ETA: 0s - reward: 0.0190
# >>> Evaluando Step 1079999 -> Avg=22.20, Max=35.00, Std=7.36 -> [22.0, 21.0, 35.0, 12.0, 21.0]
#
# >>> PER Stats (Step 776):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0191
# 21 episodes - episode_reward: 17.905 [4.000, 32.000] - ale.lives: 1.965
#
# Interval 55 (1080000 steps performed)
# 20000/20000 [==============================] - 48s 2ms/step - reward: 0.0204
# 23 episodes - episode_reward: 17.174 [5.000, 30.000] - ale.lives: 2.107
#
# Interval 56 (1100000 steps performed)
# 19999/20000 [============================>.] - ETA: 0s - reward: 0.0207
# >>> Evaluando Step 1119999 -> Avg=17.20, Max=21.00, Std=2.56 -> [14.0, 15.0, 21.0, 17.0, 19.0]
#
# >>> PER Stats (Step 236):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 56s 3ms/step - reward: 0.0207
# 24 episodes - episode_reward: 18.167 [5.000, 30.000] - ale.lives: 2.060
#
# Interval 57 (1120000 steps performed)
# 20000/20000 [==============================] - 48s 2ms/step - reward: 0.0200
# 26 episodes - episode_reward: 15.423 [4.000, 26.000] - ale.lives: 2.015
#
# Interval 58 (1140000 steps performed)
# 19987/20000 [============================>.] - ETA: 0s - reward: 0.0201
# >>> Evaluando Step 1159999 -> Avg=17.00, Max=28.00, Std=6.07 -> [28.0, 15.0, 18.0, 10.0, 14.0]
#
# >>> PER Stats (Step 582):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 57s 3ms/step - reward: 0.0202
# 25 episodes - episode_reward: 15.720 [6.000, 28.000] - ale.lives: 2.059
#
# Interval 59 (1160000 steps performed)
# 20000/20000 [==============================] - 48s 2ms/step - reward: 0.0205
# 24 episodes - episode_reward: 17.375 [5.000, 31.000] - ale.lives: 2.132
#
# Interval 60 (1180000 steps performed)
# 19980/20000 [============================>.] - ETA: 0s - reward: 0.0194
# >>> Evaluando Step 1199999 -> Avg=18.00, Max=22.00, Std=3.03 -> [22.0, 20.0, 14.0, 15.0, 19.0]
#
# >>> PER Stats (Step 600):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 57s 3ms/step - reward: 0.0195
# 26 episodes - episode_reward: 14.731 [6.000, 28.000] - ale.lives: 2.081
#
# Interval 61 (1200000 steps performed)
# 20000/20000 [==============================] - 48s 2ms/step - reward: 0.0199
# 26 episodes - episode_reward: 15.346 [4.000, 31.000] - ale.lives: 2.159
#
# Interval 62 (1220000 steps performed)
# 19989/20000 [============================>.] - ETA: 0s - reward: 0.0217
# >>> Evaluando Step 1239999 -> Avg=16.40, Max=18.00, Std=1.02 -> [16.0, 15.0, 16.0, 18.0, 17.0]
#
# >>> PER Stats (Step 85):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 56s 3ms/step - reward: 0.0217
# 24 episodes - episode_reward: 18.667 [10.000, 28.000] - ale.lives: 2.010
#
# Interval 63 (1240000 steps performed)
# 20000/20000 [==============================] - 48s 2ms/step - reward: 0.0211
# 24 episodes - episode_reward: 17.208 [1.000, 30.000] - ale.lives: 2.012
#
# Interval 64 (1260000 steps performed)
# 19990/20000 [============================>.] - ETA: 0s - reward: 0.0196
# >>> Evaluando Step 1279999 -> Avg=17.80, Max=20.00, Std=1.94 -> [15.0, 20.0, 19.0, 19.0, 16.0]
#
# >>> PER Stats (Step 11):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 58s 3ms/step - reward: 0.0196
# 26 episodes - episode_reward: 15.423 [6.000, 26.000] - ale.lives: 2.017
#
# Interval 65 (1280000 steps performed)
# 20000/20000 [==============================] - 48s 2ms/step - reward: 0.0213
# 25 episodes - episode_reward: 15.960 [0.000, 28.000] - ale.lives: 1.996
#
# Interval 66 (1300000 steps performed)
# 19987/20000 [============================>.] - ETA: 0s - reward: 0.0194
# >>> Evaluando Step 1319999 -> Avg=17.60, Max=30.00, Std=8.87 -> [18.0, 22.0, 15.0, 3.0, 30.0]
#
# >>> PER Stats (Step 476):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 58s 3ms/step - reward: 0.0194
# 26 episodes - episode_reward: 15.577 [2.000, 28.000] - ale.lives: 2.075
#
# Interval 67 (1320000 steps performed)
# 20000/20000 [==============================] - 48s 2ms/step - reward: 0.0196
# 24 episodes - episode_reward: 16.250 [4.000, 36.000] - ale.lives: 2.052
#
# Interval 68 (1340000 steps performed)
# 19980/20000 [============================>.] - ETA: 0s - reward: 0.0203
# >>> Evaluando Step 1359999 -> Avg=18.20, Max=27.00, Std=6.18 -> [27.0, 9.0, 20.0, 21.0, 14.0]
#
# >>> PER Stats (Step 621):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0203
# 26 episodes - episode_reward: 15.385 [4.000, 29.000] - ale.lives: 1.955
#
# Interval 69 (1360000 steps performed)
# 20000/20000 [==============================] - 48s 2ms/step - reward: 0.0186
# 24 episodes - episode_reward: 16.042 [2.000, 33.000] - ale.lives: 1.959
#
# Interval 70 (1380000 steps performed)
# 19994/20000 [============================>.] - ETA: 0s - reward: 0.0207
# >>> Evaluando Step 1399999 -> Avg=14.00, Max=18.00, Std=3.63 -> [18.0, 17.0, 8.0, 12.0, 15.0]
#
# >>> PER Stats (Step 232):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 57s 3ms/step - reward: 0.0208
# 26 episodes - episode_reward: 15.769 [3.000, 28.000] - ale.lives: 2.024
#
# Interval 71 (1400000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0187
# 26 episodes - episode_reward: 14.077 [4.000, 24.000] - ale.lives: 2.042
#
# Interval 72 (1420000 steps performed)
# 19994/20000 [============================>.] - ETA: 0s - reward: 0.0201
# >>> Evaluando Step 1439999 -> Avg=16.80, Max=28.00, Std=7.03 -> [18.0, 15.0, 28.0, 17.0, 6.0]
#
# >>> PER Stats (Step 283):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 57s 3ms/step - reward: 0.0201
# 24 episodes - episode_reward: 17.292 [7.000, 30.000] - ale.lives: 1.953
#
# Interval 73 (1440000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0208
# 24 episodes - episode_reward: 16.833 [2.000, 31.000] - ale.lives: 2.048
#
# Interval 74 (1460000 steps performed)
# 19984/20000 [============================>.] - ETA: 0s - reward: 0.0196
# >>> Evaluando Step 1479999 -> Avg=15.60, Max=26.00, Std=5.28 -> [12.0, 26.0, 14.0, 14.0, 12.0]
#
# >>> PER Stats (Step 423):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 57s 3ms/step - reward: 0.0196
# 26 episodes - episode_reward: 15.385 [6.000, 25.000] - ale.lives: 2.081
#
# Interval 75 (1480000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0208
# 25 episodes - episode_reward: 16.840 [6.000, 32.000] - ale.lives: 2.026
#
# Interval 76 (1500000 steps performed)
# 19982/20000 [============================>.] - ETA: 0s - reward: 0.0183
# >>> Evaluando Step 1519999 -> Avg=18.40, Max=27.00, Std=7.28 -> [22.0, 6.0, 27.0, 15.0, 22.0]
#
# >>> PER Stats (Step 302):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 58s 3ms/step - reward: 0.0183
# 27 episodes - episode_reward: 13.370 [5.000, 23.000] - ale.lives: 2.055
#
# Interval 77 (1520000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0198
# 22 episodes - episode_reward: 17.727 [5.000, 33.000] - ale.lives: 2.082
#
# Interval 78 (1540000 steps performed)
# 19990/20000 [============================>.] - ETA: 0s - reward: 0.0204
# >>> Evaluando Step 1559999 -> Avg=15.60, Max=21.00, Std=4.59 -> [18.0, 18.0, 8.0, 21.0, 13.0]
#
# >>> PER Stats (Step 808):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 58s 3ms/step - reward: 0.0204
# 24 episodes - episode_reward: 16.708 [1.000, 28.000] - ale.lives: 2.020
#
# Interval 79 (1560000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0207
# 25 episodes - episode_reward: 16.720 [7.000, 32.000] - ale.lives: 2.183
#
# Interval 80 (1580000 steps performed)
# 19996/20000 [============================>.] - ETA: 0s - reward: 0.0210
# >>> Evaluando Step 1599999 -> Avg=16.20, Max=21.00, Std=3.87 -> [21.0, 10.0, 17.0, 19.0, 14.0]
#
# >>> PER Stats (Step 331):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 58s 3ms/step - reward: 0.0210
# 25 episodes - episode_reward: 16.960 [6.000, 32.000] - ale.lives: 2.154
#
# Interval 81 (1600000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0219
# 24 episodes - episode_reward: 17.958 [7.000, 35.000] - ale.lives: 2.054
#
# Interval 82 (1620000 steps performed)
# 19978/20000 [============================>.] - ETA: 0s - reward: 0.0209
# >>> Evaluando Step 1639999 -> Avg=22.80, Max=28.00, Std=4.87 -> [15.0, 28.0, 22.0, 21.0, 28.0]
#
# >>> PER Stats (Step 591):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 60s 3ms/step - reward: 0.0209
# 26 episodes - episode_reward: 15.923 [6.000, 30.000] - ale.lives: 2.088
#
# Interval 83 (1640000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0204
# 26 episodes - episode_reward: 16.000 [7.000, 22.000] - ale.lives: 2.144
#
# Interval 84 (1660000 steps performed)
# 19992/20000 [============================>.] - ETA: 0s - reward: 0.0197
# >>> Evaluando Step 1679999 -> Avg=20.60, Max=28.00, Std=7.66 -> [27.0, 25.0, 9.0, 14.0, 28.0]
#
# >>> PER Stats (Step 104):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0197
# 27 episodes - episode_reward: 14.889 [6.000, 30.000] - ale.lives: 2.039
#
# Interval 85 (1680000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0208
# 23 episodes - episode_reward: 17.435 [2.000, 32.000] - ale.lives: 2.011
#
# Interval 86 (1700000 steps performed)
# 19994/20000 [============================>.] - ETA: 0s - reward: 0.0199
# >>> Evaluando Step 1719999 -> Avg=17.40, Max=28.00, Std=6.65 -> [22.0, 15.0, 11.0, 11.0, 28.0]
#
# >>> PER Stats (Step 870):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0198
# 25 episodes - episode_reward: 15.880 [7.000, 27.000] - ale.lives: 2.143
#
# Interval 87 (1720000 steps performed)
# 20000/20000 [==============================] - 48s 2ms/step - reward: 0.0194
# 26 episodes - episode_reward: 15.308 [5.000, 26.000] - ale.lives: 2.082
#
# Interval 88 (1740000 steps performed)
# 19989/20000 [============================>.] - ETA: 0s - reward: 0.0201
# >>> Evaluando Step 1759999 -> Avg=20.60, Max=25.00, Std=3.20 -> [21.0, 15.0, 21.0, 25.0, 21.0]
#
# >>> PER Stats (Step 674):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0200
# 25 episodes - episode_reward: 15.920 [7.000, 30.000] - ale.lives: 2.154
#
# Interval 89 (1760000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0204
# 25 episodes - episode_reward: 16.600 [6.000, 29.000] - ale.lives: 2.081
#
# Interval 90 (1780000 steps performed)
# 19987/20000 [============================>.] - ETA: 0s - reward: 0.0212
# >>> Evaluando Step 1799999 -> Avg=16.80, Max=28.00, Std=6.37 -> [28.0, 16.0, 13.0, 9.0, 18.0]
#
# >>> PER Stats (Step 78):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 58s 3ms/step - reward: 0.0211
# 25 episodes - episode_reward: 17.000 [6.000, 31.000] - ale.lives: 2.107
#
# Interval 91 (1800000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0221
# 24 episodes - episode_reward: 18.083 [0.000, 29.000] - ale.lives: 1.944
#
# Interval 92 (1820000 steps performed)
# 19999/20000 [============================>.] - ETA: 0s - reward: 0.0193
# >>> Evaluando Step 1839999 -> Avg=14.20, Max=21.00, Std=5.74 -> [20.0, 10.0, 14.0, 21.0, 6.0]
#
# >>> PER Stats (Step 717):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 57s 3ms/step - reward: 0.0192
# 22 episodes - episode_reward: 17.409 [8.000, 27.000] - ale.lives: 1.984
#
# Interval 93 (1840000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0207
# 24 episodes - episode_reward: 17.458 [6.000, 29.000] - ale.lives: 1.956
#
# Interval 94 (1860000 steps performed)
# 19982/20000 [============================>.] - ETA: 0s - reward: 0.0208
# >>> Evaluando Step 1879999 -> Avg=11.40, Max=18.00, Std=4.41 -> [9.0, 9.0, 18.0, 6.0, 15.0]
#
# >>> PER Stats (Step 755):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 55s 3ms/step - reward: 0.0208
# 22 episodes - episode_reward: 18.591 [11.000, 30.000] - ale.lives: 2.008
#
# Interval 95 (1880000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0207
# 26 episodes - episode_reward: 16.154 [5.000, 30.000] - ale.lives: 2.022
#
# Interval 96 (1900000 steps performed)
# 19987/20000 [============================>.] - ETA: 0s - reward: 0.0208
# >>> Evaluando Step 1919999 -> Avg=17.00, Max=24.00, Std=4.47 -> [16.0, 20.0, 24.0, 13.0, 12.0]
#
# >>> PER Stats (Step 840):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0208
# 24 episodes - episode_reward: 16.958 [7.000, 29.000] - ale.lives: 2.050
#
# Interval 97 (1920000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0201
# 27 episodes - episode_reward: 15.148 [5.000, 32.000] - ale.lives: 2.001
#
# Interval 98 (1940000 steps performed)
# 19979/20000 [============================>.] - ETA: 0s - reward: 0.0206
# >>> Evaluando Step 1959999 -> Avg=15.40, Max=21.00, Std=4.84 -> [14.0, 9.0, 21.0, 21.0, 12.0]
#
# >>> PER Stats (Step 640):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 57s 3ms/step - reward: 0.0206
# 21 episodes - episode_reward: 19.333 [4.000, 31.000] - ale.lives: 2.192
#
# Interval 99 (1960000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0200
# 26 episodes - episode_reward: 15.346 [7.000, 28.000] - ale.lives: 2.039
#
# Interval 100 (1980000 steps performed)
# 19994/20000 [============================>.] - ETA: 0s - reward: 0.0195
# >>> Evaluando Step 1999999 -> Avg=19.00, Max=26.00, Std=6.20 -> [26.0, 17.0, 26.0, 16.0, 10.0]
#
# >>> PER Stats (Step 35):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0194
# 26 episodes - episode_reward: 15.538 [5.000, 30.000] - ale.lives: 2.008
#
# Interval 101 (2000000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0209
# 25 episodes - episode_reward: 16.400 [0.000, 32.000] - ale.lives: 2.050
#
# Interval 102 (2020000 steps performed)
# 19993/20000 [============================>.] - ETA: 0s - reward: 0.0210
# >>> Evaluando Step 2039999 -> Avg=12.60, Max=19.00, Std=3.26 -> [11.0, 19.0, 10.0, 11.0, 12.0]
#
# >>> PER Stats (Step 411):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 56s 3ms/step - reward: 0.0209
# 26 episodes - episode_reward: 16.077 [6.000, 30.000] - ale.lives: 2.064
#
# Interval 103 (2040000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0184
# 24 episodes - episode_reward: 15.375 [5.000, 32.000] - ale.lives: 1.996
#
# Interval 104 (2060000 steps performed)
# 19986/20000 [============================>.] - ETA: 0s - reward: 0.0209
# >>> Evaluando Step 2079999 -> Avg=14.60, Max=19.00, Std=4.41 -> [19.0, 19.0, 11.0, 16.0, 8.0]
#
# >>> PER Stats (Step 247):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 58s 3ms/step - reward: 0.0209
# 23 episodes - episode_reward: 18.043 [6.000, 35.000] - ale.lives: 2.145
#
# Interval 105 (2080000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0197
# 25 episodes - episode_reward: 16.080 [7.000, 25.000] - ale.lives: 2.116
#
# Interval 106 (2100000 steps performed)
# 19996/20000 [============================>.] - ETA: 0s - reward: 0.0201
# >>> Evaluando Step 2119999 -> Avg=22.20, Max=33.00, Std=6.31 -> [33.0, 25.0, 18.0, 20.0, 15.0]
#
# >>> PER Stats (Step 599):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 61s 3ms/step - reward: 0.0202
# 24 episodes - episode_reward: 16.292 [6.000, 27.000] - ale.lives: 2.164
#
# Interval 107 (2120000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0196
# 27 episodes - episode_reward: 14.926 [7.000, 24.000] - ale.lives: 2.011
#
# Interval 108 (2140000 steps performed)
# 19983/20000 [============================>.] - ETA: 0s - reward: 0.0220
# >>> Evaluando Step 2159999 -> Avg=17.00, Max=30.00, Std=11.05 -> [13.0, 29.0, 1.0, 30.0, 12.0]
#
# >>> PER Stats (Step 1126):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 61s 3ms/step - reward: 0.0220
# 22 episodes - episode_reward: 18.818 [8.000, 30.000] - ale.lives: 2.034
#
# Interval 109 (2160000 steps performed)
# 20000/20000 [==============================] - 50s 3ms/step - reward: 0.0200
# 27 episodes - episode_reward: 15.333 [7.000, 27.000] - ale.lives: 2.096
#
# Interval 110 (2180000 steps performed)
# 19988/20000 [============================>.] - ETA: 0s - reward: 0.0201
# >>> Evaluando Step 2199999 -> Avg=17.80, Max=27.00, Std=5.56 -> [27.0, 21.0, 13.0, 12.0, 16.0]
#
# >>> PER Stats (Step 436):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0200
# 25 episodes - episode_reward: 16.440 [6.000, 24.000] - ale.lives: 2.083
#
# Interval 111 (2200000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0220
# 24 episodes - episode_reward: 18.208 [4.000, 29.000] - ale.lives: 1.994
#
# Interval 112 (2220000 steps performed)
# 19997/20000 [============================>.] - ETA: 0s - reward: 0.0216
# >>> Evaluando Step 2239999 -> Avg=16.20, Max=31.00, Std=9.20 -> [5.0, 18.0, 8.0, 31.0, 19.0]
#
# >>> PER Stats (Step 292):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0215
# 25 episodes - episode_reward: 17.400 [9.000, 29.000] - ale.lives: 2.032
#
# Interval 113 (2240000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0200
# 25 episodes - episode_reward: 15.520 [2.000, 24.000] - ale.lives: 1.963
#
# Interval 114 (2260000 steps performed)
# 19986/20000 [============================>.] - ETA: 0s - reward: 0.0214
# >>> Evaluando Step 2279999 -> Avg=20.40, Max=28.00, Std=4.50 -> [23.0, 18.0, 16.0, 17.0, 28.0]
#
# >>> PER Stats (Step 394):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 61s 3ms/step - reward: 0.0214
# 24 episodes - episode_reward: 18.125 [4.000, 31.000] - ale.lives: 2.054
#
# Interval 115 (2280000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0203
# 22 episodes - episode_reward: 18.136 [6.000, 32.000] - ale.lives: 2.058
#
# Interval 116 (2300000 steps performed)
# 19985/20000 [============================>.] - ETA: 0s - reward: 0.0201
# >>> Evaluando Step 2319999 -> Avg=18.00, Max=30.00, Std=7.92 -> [9.0, 30.0, 10.0, 18.0, 23.0]
#
# >>> PER Stats (Step 550):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 61s 3ms/step - reward: 0.0200
# 25 episodes - episode_reward: 16.280 [5.000, 34.000] - ale.lives: 2.144
#
# Interval 117 (2320000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0200
# 28 episodes - episode_reward: 13.964 [6.000, 25.000] - ale.lives: 1.990
#
# Interval 118 (2340000 steps performed)
# 19996/20000 [============================>.] - ETA: 0s - reward: 0.0192
# >>> Evaluando Step 2359999 -> Avg=23.00, Max=33.00, Std=5.06 -> [33.0, 20.0, 20.0, 22.0, 20.0]
#
# >>> PER Stats (Step 872):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 62s 3ms/step - reward: 0.0192
# 26 episodes - episode_reward: 14.538 [5.000, 30.000] - ale.lives: 1.990
#
# Interval 119 (2360000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0205
# 24 episodes - episode_reward: 17.292 [5.000, 33.000] - ale.lives: 2.058
#
# Interval 120 (2380000 steps performed)
# 19995/20000 [============================>.] - ETA: 0s - reward: 0.0196
# >>> Evaluando Step 2399999 -> Avg=19.40, Max=23.00, Std=3.20 -> [22.0, 20.0, 18.0, 23.0, 14.0]
#
# >>> PER Stats (Step 574):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 61s 3ms/step - reward: 0.0196
# 25 episodes - episode_reward: 15.680 [3.000, 26.000] - ale.lives: 2.101
#
# Interval 121 (2400000 steps performed)
# 20000/20000 [==============================] - 50s 3ms/step - reward: 0.0209
# 25 episodes - episode_reward: 16.960 [8.000, 26.000] - ale.lives: 2.073
#
# Interval 122 (2420000 steps performed)
# 19984/20000 [============================>.] - ETA: 0s - reward: 0.0210
# >>> Evaluando Step 2439999 -> Avg=14.00, Max=18.00, Std=4.94 -> [9.0, 18.0, 18.0, 18.0, 7.0]
#
# >>> PER Stats (Step 53):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0209
# 24 episodes - episode_reward: 17.833 [9.000, 31.000] - ale.lives: 2.068
#
# Interval 123 (2440000 steps performed)
# 20000/20000 [==============================] - 50s 3ms/step - reward: 0.0192
# 22 episodes - episode_reward: 17.136 [0.000, 30.000] - ale.lives: 2.040
#
# Interval 124 (2460000 steps performed)
# 19996/20000 [============================>.] - ETA: 0s - reward: 0.0199
# >>> Evaluando Step 2479999 -> Avg=16.60, Max=24.00, Std=4.76 -> [24.0, 13.0, 11.0, 15.0, 20.0]
#
# >>> PER Stats (Step 67):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0198
# 28 episodes - episode_reward: 14.429 [7.000, 28.000] - ale.lives: 2.074
#
# Interval 125 (2480000 steps performed)
# 20000/20000 [==============================] - 50s 3ms/step - reward: 0.0203
# 25 episodes - episode_reward: 15.880 [0.000, 35.000] - ale.lives: 2.052
#
# Interval 126 (2500000 steps performed)
# 19987/20000 [============================>.] - ETA: 0s - reward: 0.0199
# >>> Evaluando Step 2519999 -> Avg=15.20, Max=21.00, Std=3.71 -> [13.0, 11.0, 13.0, 18.0, 21.0]
#
# >>> PER Stats (Step 1387):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 60s 3ms/step - reward: 0.0199
# 23 episodes - episode_reward: 16.696 [6.000, 29.000] - ale.lives: 2.085
#
# Interval 127 (2520000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0208
# 26 episodes - episode_reward: 16.231 [6.000, 29.000] - ale.lives: 2.072
#
# Interval 128 (2540000 steps performed)
# 19989/20000 [============================>.] - ETA: 0s - reward: 0.0218
# >>> Evaluando Step 2559999 -> Avg=20.20, Max=29.00, Std=5.81 -> [29.0, 22.0, 12.0, 16.0, 22.0]
#
# >>> PER Stats (Step 383):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 61s 3ms/step - reward: 0.0218
# 23 episodes - episode_reward: 19.261 [5.000, 32.000] - ale.lives: 1.986
#
# Interval 129 (2560000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0206
# 27 episodes - episode_reward: 15.556 [8.000, 32.000] - ale.lives: 2.068
#
# Interval 130 (2580000 steps performed)
# 19998/20000 [============================>.] - ETA: 0s - reward: 0.0202
# >>> Evaluando Step 2599999 -> Avg=15.20, Max=26.00, Std=5.88 -> [14.0, 26.0, 14.0, 14.0, 8.0]
#
# >>> PER Stats (Step 130):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0202
# 25 episodes - episode_reward: 16.200 [7.000, 31.000] - ale.lives: 1.909
#
# Interval 131 (2600000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0209
# 23 episodes - episode_reward: 17.957 [0.000, 29.000] - ale.lives: 1.895
#
# Interval 132 (2620000 steps performed)
# 19982/20000 [============================>.] - ETA: 0s - reward: 0.0199
# >>> Evaluando Step 2639999 -> Avg=15.40, Max=23.00, Std=4.50 -> [23.0, 12.0, 11.0, 13.0, 18.0]
#
# >>> PER Stats (Step 206):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0199
# 24 episodes - episode_reward: 16.500 [4.000, 26.000] - ale.lives: 2.029
#
# Interval 133 (2640000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0200
# 25 episodes - episode_reward: 15.400 [6.000, 24.000] - ale.lives: 2.158
#
# Interval 134 (2660000 steps performed)
# 19983/20000 [============================>.] - ETA: 0s - reward: 0.0204
# >>> Evaluando Step 2679999 -> Avg=14.40, Max=19.00, Std=4.54 -> [9.0, 19.0, 9.0, 16.0, 19.0]
#
# >>> PER Stats (Step 124):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0204
# 26 episodes - episode_reward: 16.538 [6.000, 28.000] - ale.lives: 2.030
#
# Interval 135 (2680000 steps performed)
# 20000/20000 [==============================] - 50s 3ms/step - reward: 0.0206
# 24 episodes - episode_reward: 16.667 [0.000, 49.000] - ale.lives: 2.046
#
# Interval 136 (2700000 steps performed)
# 19998/20000 [============================>.] - ETA: 0s - reward: 0.0203
# >>> Evaluando Step 2719999 -> Avg=23.40, Max=33.00, Std=6.71 -> [18.0, 29.0, 15.0, 22.0, 33.0]
#
# >>> PER Stats (Step 47):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 63s 3ms/step - reward: 0.0203
# 27 episodes - episode_reward: 15.444 [1.000, 29.000] - ale.lives: 2.056
#
# Interval 137 (2720000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0201
# 26 episodes - episode_reward: 15.231 [0.000, 24.000] - ale.lives: 2.086
#
# Interval 138 (2740000 steps performed)
# 19994/20000 [============================>.] - ETA: 0s - reward: 0.0196
# >>> Evaluando Step 2759999 -> Avg=15.00, Max=19.00, Std=3.74 -> [8.0, 15.0, 17.0, 16.0, 19.0]
#
# >>> PER Stats (Step 64):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0196
# 27 episodes - episode_reward: 14.741 [5.000, 27.000] - ale.lives: 2.166
#
# Interval 139 (2760000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0211
# 26 episodes - episode_reward: 15.885 [0.000, 26.000] - ale.lives: 2.110
#
# Interval 140 (2780000 steps performed)
# 19988/20000 [============================>.] - ETA: 0s - reward: 0.0222
# >>> Evaluando Step 2799999 -> Avg=16.20, Max=28.00, Std=6.71 -> [28.0, 8.0, 16.0, 17.0, 12.0]
#
# >>> PER Stats (Step 1228):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0221
# 23 episodes - episode_reward: 18.522 [8.000, 28.000] - ale.lives: 2.024
#
# Interval 141 (2800000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0207
# 27 episodes - episode_reward: 15.704 [6.000, 30.000] - ale.lives: 2.170
#
# Interval 142 (2820000 steps performed)
# 19999/20000 [============================>.] - ETA: 0s - reward: 0.0201
# >>> Evaluando Step 2839999 -> Avg=15.80, Max=21.00, Std=3.97 -> [13.0, 21.0, 11.0, 14.0, 20.0]
#
# >>> PER Stats (Step 485):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 60s 3ms/step - reward: 0.0201
# 24 episodes - episode_reward: 17.083 [9.000, 32.000] - ale.lives: 1.901
#
# Interval 143 (2840000 steps performed)
# 20000/20000 [==============================] - 50s 3ms/step - reward: 0.0208
# 26 episodes - episode_reward: 15.846 [6.000, 27.000] - ale.lives: 2.057
#
# Interval 144 (2860000 steps performed)
# 19986/20000 [============================>.] - ETA: 0s - reward: 0.0200
# >>> Evaluando Step 2879999 -> Avg=13.20, Max=26.00, Std=8.08 -> [10.0, 1.0, 26.0, 15.0, 14.0]
#
# >>> PER Stats (Step 47):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 61s 3ms/step - reward: 0.0200
# ...
# 20000/20000 [==============================] - 58s 3ms/step - reward: 0.0195
# 23 episodes - episode_reward: 17.174 [5.000, 30.000] - ale.lives: 2.071
#
# Interval 153 (3040000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0201
# 24 episodes - episode_reward: 16.792 [5.000, 28.000] - ale.lives: 2.149
#
# Interval 154 (3060000 steps performed)
# 19989/20000 [============================>.] - ETA: 0s - reward: 0.0202
# >>> Evaluando Step 3079999 -> Avg=15.40, Max=19.00, Std=4.32 -> [19.0, 16.0, 18.0, 7.0, 17.0]
#
# >>> PER Stats (Step 149):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0203
# 24 episodes - episode_reward: 16.917 [3.000, 30.000] - ale.lives: 1.917
#
# Interval 155 (3080000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0204
# 22 episodes - episode_reward: 18.409 [3.000, 35.000] - ale.lives: 1.967
#
# Interval 156 (3100000 steps performed)
# 19988/20000 [============================>.] - ETA: 0s - reward: 0.0209
# >>> Evaluando Step 3119999 -> Avg=22.40, Max=31.00, Std=7.89 -> [24.0, 29.0, 19.0, 31.0, 9.0]
#
# >>> PER Stats (Step 185):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 62s 3ms/step - reward: 0.0209
# 23 episodes - episode_reward: 18.217 [9.000, 31.000] - ale.lives: 1.892
#
# Interval 157 (3120000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0210
# 24 episodes - episode_reward: 17.417 [4.000, 32.000] - ale.lives: 2.027
#
# Interval 158 (3140000 steps performed)
# 19982/20000 [============================>.] - ETA: 0s - reward: 0.0206
# >>> Evaluando Step 3159999 -> Avg=20.20, Max=29.00, Std=6.49 -> [9.0, 22.0, 29.0, 19.0, 22.0]
#
# >>> PER Stats (Step 1147):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 60s 3ms/step - reward: 0.0205
# 21 episodes - episode_reward: 18.810 [10.000, 32.000] - ale.lives: 1.979
#
# Interval 159 (3160000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0199
# 23 episodes - episode_reward: 17.696 [7.000, 30.000] - ale.lives: 2.075
#
# Interval 160 (3180000 steps performed)
# 19993/20000 [============================>.] - ETA: 0s - reward: 0.0205
# >>> Evaluando Step 3199999 -> Avg=15.80, Max=23.00, Std=6.01 -> [23.0, 11.0, 13.0, 9.0, 23.0]
#
# >>> PER Stats (Step 579):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 58s 3ms/step - reward: 0.0204
# 24 episodes - episode_reward: 17.417 [7.000, 27.000] - ale.lives: 2.059
#
# Interval 161 (3200000 steps performed)
# 20000/20000 [==============================] - 50s 3ms/step - reward: 0.0213
# 26 episodes - episode_reward: 16.577 [4.000, 29.000] - ale.lives: 2.083
#
# Interval 162 (3220000 steps performed)
# 19980/20000 [============================>.] - ETA: 0s - reward: 0.0207
# >>> Evaluando Step 3239999 -> Avg=22.20, Max=28.00, Std=4.96 -> [28.0, 17.0, 23.0, 16.0, 27.0]
#
# >>> PER Stats (Step 342):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 62s 3ms/step - reward: 0.0207
# 24 episodes - episode_reward: 16.792 [9.000, 28.000] - ale.lives: 2.028
#
# Interval 163 (3240000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0200
# 26 episodes - episode_reward: 15.500 [7.000, 27.000] - ale.lives: 2.054
#
# Interval 164 (3260000 steps performed)
# 19991/20000 [============================>.] - ETA: 0s - reward: 0.0206
# >>> Evaluando Step 3279999 -> Avg=15.80, Max=26.00, Std=6.62 -> [26.0, 19.0, 6.0, 13.0, 15.0]
#
# >>> PER Stats (Step 228):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0205
# 22 episodes - episode_reward: 18.636 [8.000, 35.000] - ale.lives: 2.000
#
# Interval 165 (3280000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0216
# 27 episodes - episode_reward: 16.037 [6.000, 27.000] - ale.lives: 2.003
#
# Interval 166 (3300000 steps performed)
# 19988/20000 [============================>.] - ETA: 0s - reward: 0.0212
# >>> Evaluando Step 3319999 -> Avg=14.40, Max=20.00, Std=4.59 -> [16.0, 20.0, 6.0, 15.0, 15.0]
#
# >>> PER Stats (Step 318):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 58s 3ms/step - reward: 0.0213
# 24 episodes - episode_reward: 17.875 [7.000, 30.000] - ale.lives: 2.038
#
# Interval 167 (3320000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0209
# 24 episodes - episode_reward: 17.375 [4.000, 32.000] - ale.lives: 2.122
#
# Interval 168 (3340000 steps performed)
# 19999/20000 [============================>.] - ETA: 0s - reward: 0.0213
# >>> Evaluando Step 3359999 -> Avg=16.20, Max=21.00, Std=3.76 -> [14.0, 15.0, 11.0, 21.0, 20.0]
#
# >>> PER Stats (Step 945):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0213
# 22 episodes - episode_reward: 18.409 [5.000, 32.000] - ale.lives: 2.015
#
# Interval 169 (3360000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0199
# 28 episodes - episode_reward: 14.393 [7.000, 29.000] - ale.lives: 2.036
#
# Interval 170 (3380000 steps performed)
# 19984/20000 [============================>.] - ETA: 0s - reward: 0.0199
# >>> Evaluando Step 3399999 -> Avg=18.20, Max=26.00, Std=4.62 -> [15.0, 14.0, 15.0, 21.0, 26.0]
#
# >>> PER Stats (Step 580):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 60s 3ms/step - reward: 0.0199
# 26 episodes - episode_reward: 15.731 [6.000, 30.000] - ale.lives: 2.096
#
# Interval 171 (3400000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0228
# 26 episodes - episode_reward: 17.500 [5.000, 29.000] - ale.lives: 2.011
#
# Interval 172 (3420000 steps performed)
# 19998/20000 [============================>.] - ETA: 0s - reward: 0.0198
# >>> Evaluando Step 3439999 -> Avg=17.00, Max=30.00, Std=8.10 -> [22.0, 15.0, 8.0, 30.0, 10.0]
#
# >>> PER Stats (Step 82):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0198
# 25 episodes - episode_reward: 16.320 [1.000, 30.000] - ale.lives: 2.122
#
# Interval 173 (3440000 steps performed)
# 20000/20000 [==============================] - 50s 3ms/step - reward: 0.0204
# 26 episodes - episode_reward: 15.500 [0.000, 27.000] - ale.lives: 2.019
#
# Interval 174 (3460000 steps performed)
# 19980/20000 [============================>.] - ETA: 0s - reward: 0.0216
# >>> Evaluando Step 3479999 -> Avg=14.60, Max=20.00, Std=4.45 -> [14.0, 20.0, 7.0, 14.0, 18.0]
#
# >>> PER Stats (Step 1128):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 58s 3ms/step - reward: 0.0216
# 22 episodes - episode_reward: 18.864 [7.000, 30.000] - ale.lives: 2.016
#
# Interval 175 (3480000 steps performed)
# 20000/20000 [==============================] - 50s 3ms/step - reward: 0.0193
# 29 episodes - episode_reward: 14.069 [2.000, 25.000] - ale.lives: 2.015
#
# Interval 176 (3500000 steps performed)
# 19999/20000 [============================>.] - ETA: 0s - reward: 0.0213
# >>> Evaluando Step 3519999 -> Avg=15.80, Max=23.00, Std=5.71 -> [14.0, 6.0, 17.0, 19.0, 23.0]
#
# >>> PER Stats (Step 406):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0213
# 24 episodes - episode_reward: 17.292 [7.000, 31.000] - ale.lives: 2.074
#
# Interval 177 (3520000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0203
# 26 episodes - episode_reward: 15.769 [8.000, 27.000] - ale.lives: 1.932
#
# Interval 178 (3540000 steps performed)
# 19986/20000 [============================>.] - ETA: 0s - reward: 0.0203
# >>> Evaluando Step 3559999 -> Avg=14.80, Max=21.00, Std=3.87 -> [14.0, 9.0, 21.0, 16.0, 14.0]
#
# >>> PER Stats (Step 162):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0203
# 25 episodes - episode_reward: 16.240 [4.000, 31.000] - ale.lives: 1.991
#
# Interval 179 (3560000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0211
# 24 episodes - episode_reward: 17.542 [6.000, 29.000] - ale.lives: 2.187
#
# Interval 180 (3580000 steps performed)
# 19984/20000 [============================>.] - ETA: 0s - reward: 0.0180
# >>> Evaluando Step 3599999 -> Avg=19.60, Max=23.00, Std=2.50 -> [19.0, 22.0, 17.0, 23.0, 17.0]
#
# >>> PER Stats (Step 671):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 61s 3ms/step - reward: 0.0180
# 27 episodes - episode_reward: 12.963 [4.000, 21.000] - ale.lives: 2.154
#
# Interval 181 (3600000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0209
# 25 episodes - episode_reward: 17.240 [6.000, 32.000] - ale.lives: 2.008
#
# Interval 182 (3620000 steps performed)
# 19991/20000 [============================>.] - ETA: 0s - reward: 0.0208
# >>> Evaluando Step 3639999 -> Avg=18.20, Max=26.00, Std=5.49 -> [21.0, 13.0, 11.0, 20.0, 26.0]
#
# >>> PER Stats (Step 308):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 60s 3ms/step - reward: 0.0208
# 24 episodes - episode_reward: 17.125 [8.000, 35.000] - ale.lives: 2.130
#
# Interval 183 (3640000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0198
# 25 episodes - episode_reward: 16.160 [3.000, 26.000] - ale.lives: 2.078
#
# Interval 184 (3660000 steps performed)
# 19988/20000 [============================>.] - ETA: 0s - reward: 0.0206
# >>> Evaluando Step 3679999 -> Avg=15.40, Max=30.00, Std=7.86 -> [16.0, 30.0, 13.0, 7.0, 11.0]
#
# >>> PER Stats (Step 33):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 60s 3ms/step - reward: 0.0205
# 27 episodes - episode_reward: 15.222 [7.000, 27.000] - ale.lives: 1.975
#
# Interval 185 (3680000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0218
# 25 episodes - episode_reward: 17.240 [0.000, 29.000] - ale.lives: 2.055
#
# Interval 186 (3700000 steps performed)
# 19999/20000 [============================>.] - ETA: 0s - reward: 0.0190
# >>> Evaluando Step 3719999 -> Avg=15.20, Max=21.00, Std=5.78 -> [11.0, 21.0, 18.0, 6.0, 20.0]
#
# >>> PER Stats (Step 87):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0190
# 25 episodes - episode_reward: 15.360 [3.000, 24.000] - ale.lives: 1.982
#
# Interval 187 (3720000 steps performed)
# 20000/20000 [==============================] - 50s 3ms/step - reward: 0.0200
# 22 episodes - episode_reward: 17.636 [0.000, 33.000] - ale.lives: 2.103
#
# Interval 188 (3740000 steps performed)
# 19990/20000 [============================>.] - ETA: 0s - reward: 0.0217
# >>> Evaluando Step 3759999 -> Avg=21.40, Max=23.00, Std=1.62 -> [23.0, 20.0, 19.0, 23.0, 22.0]
#
# >>> PER Stats (Step 750):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 60s 3ms/step - reward: 0.0216
# 26 episodes - episode_reward: 16.462 [6.000, 30.000] - ale.lives: 1.990
#
# Interval 189 (3760000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0203
# 26 episodes - episode_reward: 15.923 [6.000, 28.000] - ale.lives: 2.167
#
# Interval 190 (3780000 steps performed)
# 19989/20000 [============================>.] - ETA: 0s - reward: 0.0196
# >>> Evaluando Step 3799999 -> Avg=17.00, Max=23.00, Std=6.16 -> [6.0, 19.0, 15.0, 23.0, 22.0]
#
# >>> PER Stats (Step 474):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0196
# 25 episodes - episode_reward: 15.920 [7.000, 31.000] - ale.lives: 1.984
#
# Interval 191 (3800000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0209
# 25 episodes - episode_reward: 16.840 [4.000, 30.000] - ale.lives: 2.044
#
# Interval 192 (3820000 steps performed)
# 19992/20000 [============================>.] - ETA: 0s - reward: 0.0200
# >>> Evaluando Step 3839999 -> Avg=18.80, Max=24.00, Std=4.12 -> [17.0, 24.0, 13.0, 23.0, 17.0]
#
# >>> PER Stats (Step 42):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 60s 3ms/step - reward: 0.0199
# 24 episodes - episode_reward: 16.625 [6.000, 29.000] - ale.lives: 2.068
#
# Interval 193 (3840000 steps performed)
# 20000/20000 [==============================] - 49s 2ms/step - reward: 0.0215
# 22 episodes - episode_reward: 19.045 [0.000, 33.000] - ale.lives: 2.053
#
# Interval 194 (3860000 steps performed)
# 19992/20000 [============================>.] - ETA: 0s - reward: 0.0228
# >>> Evaluando Step 3879999 -> Avg=16.00, Max=22.00, Std=4.56 -> [20.0, 12.0, 22.0, 10.0, 16.0]
#
# >>> PER Stats (Step 215):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 57s 3ms/step - reward: 0.0227
# 23 episodes - episode_reward: 20.087 [9.000, 32.000] - ale.lives: 2.127
#
# Interval 195 (3880000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0204
# 26 episodes - episode_reward: 14.962 [2.000, 26.000] - ale.lives: 2.061
#
# Interval 196 (3900000 steps performed)
# 19984/20000 [============================>.] - ETA: 0s - reward: 0.0197
# >>> Evaluando Step 3919999 -> Avg=13.20, Max=19.00, Std=4.12 -> [15.0, 15.0, 9.0, 8.0, 19.0]
#
# >>> PER Stats (Step 300):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 58s 3ms/step - reward: 0.0197
# 25 episodes - episode_reward: 16.400 [6.000, 34.000] - ale.lives: 2.014
#
# Interval 197 (3920000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0205
# 26 episodes - episode_reward: 15.846 [5.000, 31.000] - ale.lives: 2.084
#
# Interval 198 (3940000 steps performed)
# 19995/20000 [============================>.] - ETA: 0s - reward: 0.0208
# >>> Evaluando Step 3959999 -> Avg=14.40, Max=22.00, Std=6.41 -> [9.0, 22.0, 12.0, 22.0, 7.0]
#
# >>> PER Stats (Step 431):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0208
# 25 episodes - episode_reward: 16.360 [5.000, 28.000] - ale.lives: 2.026
#
# Interval 199 (3960000 steps performed)
# 20000/20000 [==============================] - 50s 2ms/step - reward: 0.0200
# 27 episodes - episode_reward: 15.000 [6.000, 27.000] - ale.lives: 2.075
#
# Interval 200 (3980000 steps performed)
# 19989/20000 [============================>.] - ETA: 0s - reward: 0.0192
# >>> Evaluando Step 3999999 -> Avg=17.20, Max=22.00, Std=5.08 -> [21.0, 21.0, 11.0, 22.0, 11.0]
#
# >>> PER Stats (Step 734):
#     Beta: 0.4000
#     Memory size: 40057
#     Max priority: 1.0000
#     Tree total: 40057.00
# 20000/20000 [==============================] - 59s 3ms/step - reward: 0.0192
# done, took 10826.323 seconds

# %%
from gym.wrappers import Monitor

# cargar mejor modelo"
dqn.load_weights('best_model_weights_4M.h5f')

# test normal + guardar recompensas
history = dqn.test(env, nb_episodes=1000, visualize=False)
episode_rewards = history.history['episode_reward']
np.save('test_rewards_4M.npy', episode_rewards)

# Mostrar los resultados
mejor_reward = np.max(episode_rewards)
mejor_epi = np.argmax(episode_rewards) + 1
print(f"\nPromedio de recompensas: {np.mean(history.history['episode_reward'])}")
print(f"Mejor Episodio {mejor_epi} con Recompensa = {mejor_reward}")

# Guardar la mejor recompensa en un archivo
with open('mejor_ejecucion_4M.txt', 'w') as f:
    f.write(f"Mejor episodio: {mejor_epi} con Recompensa: {mejor_reward}\n")
    
# correr episodio con video
# video_env = Monitor(gym.make(env_name), './video', force=True)
# dqn.test(video_env, nb_episodes=1, visualize=False)
# video_env.close()
# Out:
# Testing for 1000 episodes ...
# Episode 1: reward: 26.000, steps: 1166
# Episode 2: reward: 6.000, steps: 495
# Episode 3: reward: 16.000, steps: 948
# Episode 4: reward: 20.000, steps: 805
# Episode 5: reward: 17.000, steps: 701
# Episode 6: reward: 10.000, steps: 371
# Episode 7: reward: 18.000, steps: 890
# Episode 8: reward: 33.000, steps: 1427
# Episode 9: reward: 7.000, steps: 516
# Episode 10: reward: 14.000, steps: 762
# Episode 11: reward: 13.000, steps: 951
# Episode 12: reward: 22.000, steps: 1300
# Episode 13: reward: 12.000, steps: 610
# Episode 14: reward: 20.000, steps: 761
# Episode 15: reward: 23.000, steps: 1126
# Episode 16: reward: 9.000, steps: 498
# Episode 17: reward: 21.000, steps: 847
# Episode 18: reward: 22.000, steps: 812
# Episode 19: reward: 5.000, steps: 568
# Episode 20: reward: 33.000, steps: 1345
# Episode 21: reward: 18.000, steps: 1046
# Episode 22: reward: 22.000, steps: 926
# Episode 23: reward: 21.000, steps: 942
# Episode 24: reward: 20.000, steps: 1234
# Episode 25: reward: 32.000, steps: 1250
# Episode 26: reward: 12.000, steps: 810
# Episode 27: reward: 23.000, steps: 911
# Episode 28: reward: 16.000, steps: 783
# Episode 29: reward: 16.000, steps: 670
# Episode 30: reward: 20.000, steps: 995
# Episode 31: reward: 16.000, steps: 658
# Episode 974: reward: 23.000, steps: 1054
# Episode 975: reward: 21.000, steps: 893
# Episode 976: reward: 9.000, steps: 415
# Episode 977: reward: 11.000, steps: 838
# Episode 978: reward: 17.000, steps: 765
# Episode 979: reward: 17.000, steps: 850
# Episode 980: reward: 29.000, steps: 1020
# Episode 981: reward: 15.000, steps: 742
# Episode 982: reward: 25.000, steps: 1056
# Episode 983: reward: 16.000, steps: 853
# Episode 984: reward: 12.000, steps: 924
# Episode 985: reward: 25.000, steps: 1156
# Episode 986: reward: 13.000, steps: 705
# Episode 987: reward: 23.000, steps: 1025
# Episode 988: reward: 13.000, steps: 617
# Episode 989: reward: 25.000, steps: 936
# Episode 990: reward: 30.000, steps: 1237
# Episode 991: reward: 12.000, steps: 778
# Episode 992: reward: 14.000, steps: 669
# Episode 993: reward: 18.000, steps: 872
# Episode 994: reward: 32.000, steps: 1151
# Episode 995: reward: 23.000, steps: 1322
# Episode 996: reward: 7.000, steps: 491
# Episode 997: reward: 25.000, steps: 1020
# Episode 998: reward: 24.000, steps: 1201
# Episode 999: reward: 13.000, steps: 740
# Episode 1000: reward: 9.000, steps: 551
#
# Promedio de recompensas: 16.658
# Mejor Episodio 520 con Recompensa = 41.0

# %%
import matplotlib.pyplot as plt
rewards = np.load('test_rewards_4M.npy')
plt.figure(figsize=(14, 10))
plt.plot(rewards)
plt.title("Recompensa por episodio")
plt.xlabel("Episodio")
plt.ylabel("Recompensa")
plt.grid()
plt.savefig("grafico_recompensas_4M.png")
plt.show()

# %%
plt.figure(figsize=(14, 10))
plt.hist(rewards, bins=range(int(min(rewards)), int(max(rewards)) + 2), edgecolor='black')
plt.title('Histograma de Recompensas.test')
plt.xlabel('Recompensa por Episodio')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %% [markdown]
# 3. Justificación de los parámetros seleccionados y de los resultados obtenidos

# %%
import matplotlib.pyplot as plt

# Simulación de un resumen de PER Stats extraído de los logs
per_stats_counts = {
    'Memory size': [],
    'Tree total': [],
    'Max priority': []
}

# Simulación: 100 bloques de log con valores constantes
for _ in range(100):
    per_stats_counts['Memory size'].append(40057)
    per_stats_counts['Tree total'].append(40057.0)
    per_stats_counts['Max priority'].append(1.0)

# Crear histogramas para los tres indicadores PER
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

axes[0].hist(per_stats_counts['Memory size'], bins=10, edgecolor='black')
axes[0].set_title('Distribución Memory size')
axes[0].set_xlabel('Memory size')
axes[0].set_ylabel('Frecuencia')

axes[1].hist(per_stats_counts['Tree total'], bins=10, edgecolor='black')
axes[1].set_title('Distribución Tree total')
axes[1].set_xlabel('Tree total')

axes[2].hist(per_stats_counts['Max priority'], bins=10, edgecolor='black')
axes[2].set_title('Distribución Max priority')
axes[2].set_xlabel('Max priority')

plt.tight_layout()
plt.show()

# %%
#%pip uninstall tensorflow
#%pip install tensorflow-gpu==2.5.0
# %pip install cudatoolkit==11.2
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement cudatoolkit==11.2 (from versions: none)
# ERROR: No matching distribution found for cudatoolkit==11.2

# %% [markdown]
# ---
